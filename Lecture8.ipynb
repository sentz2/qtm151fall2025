# %% [markdown]
# # <span style="color:red"> Lecture 8: Application - Simulating Random Variables </span>

# %% [markdown]
# <font size="5">
#
# In this class we will:
#
# - Use loops within an actual context: simulating random variables
# - Notebook also contains

# %% [markdown]
# ## <span style="color:red"> I. Import Libraries </span>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:red"> II. Visualizing Random Variables </span>

# %% [markdown]
# <font size = "5" >
#
# Consider a sample with $n$ observations
#
# $ X = \begin{pmatrix} X_1 \\ X_2 \\ \vdots \\ X_n \end{pmatrix}.$

# %% [markdown]
# <font size = "5" > We can simulate from different probability distributions. Some common ones are:
#
# - The normal distribution with mean $\mu$ and standard deviation (s.d.) $\sigma$
#     - The **standard** normal distribution has mean $\mu = 0$ and s.d. $\sigma = 1$
# - The $\chi^2$-distribution ("chi-squared") with $k$ degrees of freedom.
#     - If you take $k$ standard normal samples and add up their squares, you get a single sample from a chi-squared distribution with $k$ degrees of freedom.
# - The uniform distribution with endpoints $a < b$.

# %%
# Set sample size
n = 10000

# Draw n samples from normal distribution with mean = -2, s.d. = 6
normal_samples = np.random.normal(loc = -2, scale = 6, size = n)

# Draw n samples from chi-squared distribution with 4 degrees of freedom
chisqr_samples = np.random.chisquare(df = 4, size = n)

# Draw n samples from uniform distribution with a = -3, b = 5
unif_samples = np.random.uniform(low = -3, high = 5, size = n)

# %%
# np.random.normal and np.random.uniform have some default inputs

# Draw n samples from standard normal distribution (mean = 0, s.d. = 1)
# Default: loc = 0
# Default: scale = 1
std_normal_samples = np.random.normal(size = n)

# Draw n samples from uniform distribution over unit interval (a = 0, b = 1)
# Default: low = 0
# Default: high = 1
unit_unif_samples = np.random.uniform(size = n)

# %% [markdown]
# <font size = "5">
#
# The sample average is defined as
#
# $$ \bar{X} = \frac{1}{n}\sum_{i=1}^n X_i $$

# %%
# Let's print of each of the above random variables

print(normal_samples.mean())
print(chisqr_samples.mean())
print(unif_samples.mean())
print(std_normal_samples.mean())
print(unit_unif_samples.mean())
# Out:
# -2.0353851646774896
# 3.9881060717486734
# 0.9927049318230773
# 0.0068909523498284185
# 0.49531467262780404

# %%
# Could also do:
print(np.mean(normal_samples))
print(np.mean(chisqr_samples))
print(np.mean(unif_samples))
print(np.mean(std_normal_samples))
print(np.mean(unit_unif_samples))
# Out:
# -2.0353851646774896
# 3.9881060717486734
# 0.9927049318230773
# 0.0068909523498284185
# 0.49531467262780404

# %%
# each distribution has an expected value (theoretical mean)
print("Theoretical mean for normal_samples: ", -2)
print("Theoretical mean for chisqr_samples: ", 4)
print("Theoretical mean for unif_samples: ", 1)
print("Theoretical mean for std_normal_samples: ", 0)
print("Theoretical mean for unit_unif_samples: ", 0.5)
# Out:
# Theoretical mean for normal_samples:  -2
# Theoretical mean for chisqr_samples:  4
# Theoretical mean for unif_samples:  1
# Theoretical mean for std_normal_samples:  0
# Theoretical mean for unit_unif_samples:  0.5

# %% [markdown]
# <font size = "5" >
#
# Multiple plots in a row (subplot)
#
# - The probability density function (pdf) of the normal distribution has a bell shape
# - The pdf of the uniform distribution has a rectangular shape
# - We can make an **approximate** plot of the pdf by creating a histogram of the generated samples

# %%
#------------------------ Setting up subplots----------------------------------#
# Create a plot with 1 row, 2 columns
# First, create a "matplotlib Figure" and an array of "sub-figures"

fig, subfig_array = plt.subplots(nrows = 1, ncols = 2,figsize = (6,3))

# plt.subplots has TWO outputs, so we assign the output to TWO variables
# The names we give them are OUR CHOICE
# The option "figsize" indicates the (width,height)) of the graph.
# The complete figure will be 6 inches wide, 3 inches tall


# First Sub-Figure
subfig_array[0].hist(x = normal_samples)
subfig_array[0].set_title("Normal Distribution\n with mean -2, s.d. 6")
subfig_array[0].set_xlabel("Sample Value")
subfig_array[0].set_ylabel("Frequency")

# Second Figure
subfig_array[1].hist(x = unif_samples)
subfig_array[1].set_title("Uniform Distribution\n over [-3, 5]")
subfig_array[1].set_xlabel("Sample Value")
subfig_array[1].set_ylabel("Frequency")

# The tight layout option ensures that the axes are not overlapping
# plt.tight_layout()


plt.show()

# %% [markdown]
# <font size = "5">
#
# Now, let's do a version with three plots in the same row. We'll add the histogram of the chi-squared samples too

# %%
fig, subfig_array = plt.subplots(1, 3, figsize = (9,3))

# First sub-figure
subfig_array[0].hist(x = normal_samples)
subfig_array[0].set_title("Normal Distribution\n with mean -2, s.d. 6")
subfig_array[0].set_xlabel("Sample Value")
subfig_array[0].set_ylabel("Frequency")

# Second sub-figure
subfig_array[1].hist(x = unif_samples)
subfig_array[1].set_title("Uniform Distribution\n over [-3, 5]")
subfig_array[1].set_xlabel("Sample Value")
subfig_array[1].set_ylabel("Frequency")

# Third sub-figure
subfig_array[2].hist(x = chisqr_samples)
subfig_array[2].set_title("Chi Square Distribution\n with 4 degrees of freedom")
subfig_array[2].set_xlabel("Sample Value")
subfig_array[2].set_ylabel("Frequency")

# The tight layout option ensures that the axes are not overlapping
plt.tight_layout()

# %% [markdown]
# <font size = "5">
#
# - Now we make a figure with 4 plots arranged in a 2x2 pattern
# - Compare standard normal with our normal
# - Compare uniform over [0, 1] with uniform over [-3,5]

# %%
fig, subfig_array = plt.subplots(2, 2, figsize = (6,6))

# First sub-figure
subfig_array[0,0].hist(x = normal_samples)
subfig_array[0,0].set_title("Normal Distribution\n with mean -2, s.d. 6")
subfig_array[0,0].set_xlabel("Sample Value")
subfig_array[0,0].set_ylabel("Frequency")

# second sub-figure
subfig_array[0,1].hist(x = std_normal_samples)
subfig_array[0,1].set_title("Normal Distribution\n with mean 0, s.d. 1")
subfig_array[0,1].set_xlabel("Sample Value")
subfig_array[0,1].set_ylabel("Frequency")

# third sub-figure
subfig_array[1,0].hist(x = unif_samples)
subfig_array[1,0].set_title("Uniform Distribution\n over [-3, 5]")
subfig_array[1,0].set_xlabel("Sample Value")
subfig_array[1,0].set_ylabel("Frequency")


# fourth sub-figure
subfig_array[1,1].hist(x = unit_unif_samples)
subfig_array[1,1].set_title("Uniform Distribution\n over [0, 1]")
subfig_array[1,1].set_xlabel("Sample Value")
subfig_array[1,1].set_ylabel("Frequency")

# The tight layout option ensures that the axes are not overlapping
plt.tight_layout()

# %% [markdown]
# ## <span style="color:red"> III. Single Loops </span>

# %% [markdown]
# <font size = "5">
#
# How does $\bar{X}$ change over different samples of the same size?

# %%
# store sample mean in a list
list_xbar = [None, None, None, None]
sample_size = 100

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[0] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[1] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[2] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[3] = vec_unif.mean()

print(list_xbar)
print()
print(np.array(list_xbar))
print("Theoretical mean: ", 0)
# Out:
# [np.float64(0.03515297757264197), np.float64(0.25325120056906814), np.float64(-0.016116945651770763), np.float64(0.0023317857218451855)]
#
# [ 0.03515298  0.2532512  -0.01611695  0.00233179]
# Theoretical mean:  0

# %%
# store sample mean in a numpy array (vector)
# vec_xbar = np.array([None, None, None, None])

# starting with zeros is more simple than starting with "None"
vec_xbar = np.zeros(4)


sample_size = 100

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[0] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[1] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[2] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[3] = vec_unif.mean()

print(vec_xbar)
print("Theoretical mean: ", 0)
# Out:
# [-0.0870298  -0.0810099  -0.01690776 -0.04767652]
# Theoretical mean:  0

# %%
# We will draw random sample "num_simulations" times
# Each time we will create a random vector of size "sample_size"
# In this example we will generate values from a uniform between -2 and 2.

num_simulations = 2000
sample_size     = 100

# using an array starting with zeros
vec_xbar = np.zeros(num_simulations)

# or array filled with None
# vec_xbar = np.full(num_simulations, None, dtype=object)

# using a list
list_xbar = [None] * num_simulations

for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
    list_xbar[iteration] = vec_unif.mean()


plt.hist(x = vec_xbar)
plt.title("Distribution of Xbar with different simulated samples")
plt.ylabel("Frequency")
plt.xlabel("Values of Xbar")
plt.show()

# %% [markdown]
# ## <span style="color:red"> IV. Nested Loops </span>

# %% [markdown]
# <font size = "5">
#
# What happens to $\bar{X}$ with different $n$?
#
# - The Central Limit Theorem makes a prediction!
# - It says that the distribution will have a bell shape with higher $n$.

# %%
# One way is to write this with repeated code chunks
# We just repeat the code that we had above, with different sample sizes
# Each time will start the process of generating new data from scratch.

fig, subfig_array = plt.subplots(1, 3, figsize = (9,3))

num_simulations = 2000

# Simulate with sample size one
sample_size = 1
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
subfig_array[0].hist(vec_xbar)
subfig_array[0].set_title("Distribution of Xbar with size 1")
subfig_array[0].set_ylabel("Frequency")
subfig_array[0].set_xlabel("Values of Xbar")


# Simulate with sample size 10
sample_size = 10
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
subfig_array[1].hist(vec_xbar)
subfig_array[1].set_title("Distribution of Xbar with size 10")
subfig_array[1].set_ylabel("Frequency")
subfig_array[1].set_xlabel("Values of Xbar")

# Simulate with sample size 50
sample_size = 50
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
subfig_array[2].hist(vec_xbar)
subfig_array[2].set_title("Distribution of Xbar with size 50")
subfig_array[2].set_ylabel("Frequency")
subfig_array[2].set_xlabel("Values of Xbar")

plt.tight_layout()
plt.show()

# %%
# Let's make all 3 plots have consistent x and y limits

fig, subfig_array = plt.subplots(1, 3, figsize = (9,3))

num_simulations = 2000

# Simulate with sample size one
sample_size = 1
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()


subfig_array[0].hist(vec_xbar)
subfig_array[0].set_title("Distribution of Xbar with size 1")
subfig_array[0].set_ylabel("Frequency")
subfig_array[0].set_xlabel("Values of Xbar")
subfig_array[0].set_xlim(-2,2)


# Simulate with sample size 10
sample_size = 10
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()


subfig_array[1].hist(vec_xbar)
subfig_array[1].set_title("Distribution of Xbar with size 10")
subfig_array[1].set_ylabel("Frequency")
subfig_array[1].set_xlabel("Values of Xbar")
subfig_array[1].set_xlim(-2,2)

# Simulate with sample size 50
sample_size = 50
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()


subfig_array[2].hist(vec_xbar)
subfig_array[2].set_title("Distribution of Xbar with size 50")
subfig_array[2].set_ylabel("Frequency")
subfig_array[2].set_xlabel("Values of Xbar")
subfig_array[2].set_xlim(-2,2)

subfig_array[0].set_ylim(top=525)
subfig_array[1].set_ylim(top=525)
subfig_array[2].set_ylim(top=525)

plt.tight_layout()
plt.show()

# %% [markdown]
# <font size = "5">
# Let's do with with 2 for loops, one inside the other. (Nested loops)

# %%
num_simulations = 2000
sample_size_list = [1,10,50,100,150,200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]

N = len(sample_size_list)

fig, subfig_array = plt.subplots(2, 3, figsize = (9,6))

xmin = -2
xmax = 2
ymax = 550

for k in range(N):
    sample_sz = sample_size_list[k]
    row = fig_row[k]
    col = fig_col[k]

    vec_xbar = np.zeros(num_simulations)
    for iteration in range(num_simulations):
        vec_unif  = np.random.uniform(low = -2, high=2, size = sample_sz)
        vec_xbar[iteration] = vec_unif.mean()

    subfig_array[row,col].hist(vec_xbar)
    subfig_array[row,col].set_title("Distribution of Xbar with\n sample size " + str(sample_sz))
    subfig_array[row,col].set_ylabel("Frequency")
    subfig_array[row,col].set_xlabel("Values of Xbar") 
    subfig_array[row,col].set_xlim(xmin,xmax) 
    subfig_array[row,col].set_ylim(top=ymax)  

plt.tight_layout()
plt.show()

# %% [markdown]
# <font size = "5">
# Notice that our loop variable "k" traversed the values 0, 1, 2, 3, 4, 5. But the only reason we needed these values was because we needed to access the k-th element of 3 lists.
# <br>
#
# ```python
#     sample_sz = sample_size_list[k]
#     row = fig_row[k]
#     col = fig_col[k]
# ```
#
# The only purpose of "k" was to define these 3 elements. Ideally we would like to do something like:
# <br>
#
# ```python
#     for sample_sz, row, col in something:
# ```
#
# The ``zip`` function allows us to create an appropiate object for "something"

# %%
print(zip(sample_size_list, fig_row, fig_col)) # not helpful at all..
# Out:
# <zip object at 0x173e8b680>

# %%
print(list(zip(sample_size_list, fig_row, fig_col)))
# Out:
# [(1, 0, 0), (10, 0, 1), (50, 0, 2), (100, 1, 0), (150, 1, 1), (200, 1, 2)]

# %%
num_simulations = 2000
sample_size_list = [1,10,50,100,150,200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]


fig, subfig_array = plt.subplots(2, 3, figsize = (9,6))

xmin = -2
xmax = 2
ymax = 600

for sample_sz, row, col in zip(sample_size_list, fig_row, fig_col):

    vec_xbar = np.zeros(num_simulations)
    for iteration in range(num_simulations):
        vec_unif  = np.random.uniform(low = -2, high=2, size = sample_sz)
        vec_xbar[iteration] = vec_unif.mean()

    subfig_array[row,col].hist(vec_xbar)
    subfig_array[row,col].set_title("Distribution of Xbar with\n sample size " + str(sample_sz))
    subfig_array[row,col].set_ylabel("Frequency")
    subfig_array[row,col].set_xlabel("Values of Xbar") 
    subfig_array[row,col].set_xlim(xmin,xmax) 
    subfig_array[row,col].set_ylim(top=ymax)  

plt.tight_layout()
plt.show()

# %% [markdown]
# <font size = "5">
# Try it yourself!
#
# - Repeat the above simulation with a few changes
# - Write code that puts all the figures in the same row
# - Use a Chi-square distribution with (df = 1) instead of a normal

# %%
# Write your own solution
print(list(zip(sample_size_list, fig_row, fig_col)))
sample_size_list = [5, 10, 20, 50, 100, 200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]
num_simulations = 1000

fig, subfig_array = plt.subplots(1, len(sample_size_list), figsize = (18, 3))
xmin = -2
xmax = 2
ymax = 600

for ax, sample_sz in zip(subfig_array, sample_size_list):
    vec_xbar = np.zeros(num_simulations)
    for iteration in range(num_simulations):
        vec_unif = np.random.chisquare(df=1, size = sample_sz)
        vec_xbar[iteration] = vec_unif.mean()

    ax.hist(vec_xbar, bins=30)
    ax.set_title(f"Distribution of Xbar with\n sample size {sample_sz}")
    ax.set_xlabel("Values of X")
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(top=ymax)

plt.tight_layout()
plt.show()
# Out:
# [(1, 0, 0), (10, 0, 1), (50, 0, 2), (100, 1, 0), (150, 1, 1), (200, 1, 2)]

# %% [markdown]
# ## <span style="color:red"> V. (Extra content) Loops + If/else </span>

# %% [markdown]
# <font size = "5">
#
# Let "sample_stdv" be the sample standard deviation of $X_i$.

# %%
# Parameters of a normal random variable
n                 = 10000
population_mean   = 2
population_stdv   = 5

# Create random variable and produce summary statistics
X           = np.random.normal(loc = 2,scale = 5,size = n)
Xbar        = X.mean()
sample_stdv = X.std()

# Check that the sample and standard deviation are close to their
# population values
print(Xbar)
print(sample_stdv)
# Out:
# 2.023122527815682
# 5.010507960039048

# %% [markdown]
# <font size = "5">
#
# A 95\% normal confidence interval is defined by $\ldots$
#
# - lower_bound = $\bar{X} -1.96 \times  \frac{\text{sample\_stdv}}{\sqrt{n}}$.
# - upper_bound = $\bar{X} + 1.96 \times \frac{\text{sample\_stdv}}{\sqrt{n}}$.

# %%
# Compute new variables for the upper and lower bound

lower_bound = Xbar - 1.96*(sample_stdv / np.sqrt(n))
upper_bound = Xbar + 1.96*(sample_stdv / np.sqrt(n))

# %% [markdown]
# <font size = "5">
# Try it yourself! Write an if/else that checks whether <br>
#
# lower_bound $\quad \le \quad $ population_mean $\quad \le \quad$ upper_bound

# %%
# Write your own code
n                 = 10000
population_mean   = 2
population_stdv   = 5
X           = np.random.normal(loc = 2,scale = 5,size = n)
Xbar        = X.mean()
sample_stdv = X.std()
lower_bound = Xbar - 1.96*(sample_stdv / np.sqrt(n))
upper_bound = Xbar + 1.96*(sample_stdv / np.sqrt(n))

if lower_bound <= population_mean <= upper_bound:
        print("Lower bound <= Population Mean <= Upper bound")
else: 
        print("Population Mean is Not in the interval")
print(lower_bound)
print(upper_bound)
print(population_mean)
# Out:
# Lower bound <= Population Mean <= Upper bound
# 1.8446592694716692
# 2.038010922570922
# 2

# %% [markdown]
# <font size ="5">
#
# Try it yourself! Test whether this is a 95% confidence interval

# %% [markdown]
# <font size = "3">
#
# Procedure:
# - Create a variable called "num_simulations" with value 1000
# - Create the simulation parameters "n", "population_mean", "populations_stdv".
# - Create an empty vector called "list_test_confidenceinterval".
# - Create a loop. At each iteration:
#
#     - Create a vector of normal random variables of size "n".
#     - Create a variable "test_confidenceinterval", which tests:
#
#         lower_bound $\quad \le \quad $ population_mean $\quad \le \quad$ upper_bound
#     - Append "test_confidenceinterval" to the above list
#
# - Compute the mean of "list_test_confidenceinterval"
#
# Note: The final result should be close to 95%.

# %%
# Write your own  code:
num_simulations = 1000
n = 10000
population_mean = 2
populations_stdv = 5
list_test_confidenceinterval = []
for iteration in range(num_simulations):
    X = np.random.normal(loc = population_mean, scale = populations_stdv, size = n)
    Xbar = X.mean()
    sample_stdv = X.std()
    lower_bound = Xbar - 1.96*(sample_stdv / np.sqrt(n))
    upper_bound = Xbar + 1.96*(sample_stdv / np.sqrt(n))
    if lower_bound <= population_mean <= upper_bound:
        list_test_confidenceinterval.append(1)
        coverage = np.mean(list_test_confidenceinterval)
        print("Coverage probability:", coverage)
    else: 
        list_test_confidenceinterval.append(0)
        print("Coverage probability not in the intervals")
# Out:
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability not in the intervals
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.9583333333333334
# Coverage probability: 0.96
# Coverage probability not in the intervals
# Coverage probability: 0.9259259259259259
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9333333333333333
# Coverage probability: 0.9354838709677419
# Coverage probability: 0.9375
# Coverage probability: 0.9393939393939394
# Coverage probability: 0.9411764705882353
# Coverage probability: 0.9428571428571428
# Coverage probability: 0.9444444444444444
# Coverage probability: 0.9459459459459459
# Coverage probability: 0.9473684210526315
# Coverage probability: 0.9487179487179487
# Coverage probability: 0.95
# Coverage probability: 0.9512195121951219
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9534883720930233
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9555555555555556
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.9574468085106383
# Coverage probability: 0.9583333333333334
# Coverage probability not in the intervals
# Coverage probability: 0.94
# Coverage probability: 0.9411764705882353
# Coverage probability: 0.9423076923076923
# Coverage probability: 0.9433962264150944
# Coverage probability: 0.9444444444444444
# Coverage probability: 0.9454545454545454
# Coverage probability: 0.9464285714285714
# Coverage probability: 0.9473684210526315
# Coverage probability: 0.9482758620689655
# Coverage probability: 0.9491525423728814
# Coverage probability: 0.95
# Coverage probability: 0.9508196721311475
# Coverage probability: 0.9516129032258065
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.953125
# Coverage probability: 0.9538461538461539
# Coverage probability not in the intervals
# Coverage probability: 0.9402985074626866
# Coverage probability not in the intervals
# Coverage probability: 0.927536231884058
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9295774647887324
# Coverage probability: 0.9305555555555556
# Coverage probability: 0.9315068493150684
# Coverage probability: 0.9324324324324325
# Coverage probability: 0.9333333333333333
# Coverage probability: 0.9342105263157895
# Coverage probability: 0.935064935064935
# Coverage probability: 0.9358974358974359
# Coverage probability: 0.9367088607594937
# Coverage probability: 0.9375
# Coverage probability: 0.9382716049382716
# Coverage probability: 0.9390243902439024
# Coverage probability: 0.9397590361445783
# Coverage probability not in the intervals
# Coverage probability: 0.9294117647058824
# Coverage probability: 0.9302325581395349
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9318181818181818
# Coverage probability: 0.9325842696629213
# Coverage probability: 0.9333333333333333
# Coverage probability: 0.9340659340659341
# Coverage probability: 0.9347826086956522
# Coverage probability: 0.9354838709677419
# Coverage probability: 0.9361702127659575
# Coverage probability: 0.9368421052631579
# Coverage probability: 0.9375
# Coverage probability: 0.9381443298969072
# Coverage probability: 0.9387755102040817
# Coverage probability: 0.9393939393939394
# Coverage probability: 0.94
# Coverage probability: 0.9405940594059405
# Coverage probability: 0.9411764705882353
# Coverage probability: 0.941747572815534
# Coverage probability: 0.9423076923076923
# Coverage probability not in the intervals
# Coverage probability: 0.9339622641509434
# Coverage probability not in the intervals
# Coverage probability: 0.9259259259259259
# Coverage probability: 0.926605504587156
# Coverage probability: 0.9272727272727272
# Coverage probability: 0.9279279279279279
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9292035398230089
# Coverage probability: 0.9298245614035088
# Coverage probability: 0.9304347826086956
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9316239316239316
# Coverage probability: 0.9322033898305084
# Coverage probability: 0.9327731092436975
# Coverage probability: 0.9333333333333333
# Coverage probability: 0.9338842975206612
# Coverage probability: 0.9344262295081968
# Coverage probability: 0.9349593495934959
# Coverage probability: 0.9354838709677419
# Coverage probability: 0.936
# Coverage probability: 0.9365079365079365
# Coverage probability: 0.937007874015748
# Coverage probability: 0.9375
# Coverage probability: 0.937984496124031
# Coverage probability: 0.9384615384615385
# Coverage probability not in the intervals
# Coverage probability: 0.9318181818181818
# Coverage probability not in the intervals
# Coverage probability: 0.9253731343283582
# Coverage probability: 0.9259259259259259
# Coverage probability: 0.9264705882352942
# Coverage probability: 0.927007299270073
# Coverage probability: 0.927536231884058
# Coverage probability: 0.9280575539568345
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9290780141843972
# Coverage probability: 0.9295774647887324
# Coverage probability: 0.9300699300699301
# Coverage probability: 0.9305555555555556
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9315068493150684
# Coverage probability: 0.9319727891156463
# Coverage probability: 0.9324324324324325
# Coverage probability: 0.9328859060402684
# Coverage probability: 0.9333333333333333
# Coverage probability not in the intervals
# Coverage probability: 0.9276315789473685
# Coverage probability: 0.9281045751633987
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9290322580645162
# Coverage probability: 0.9294871794871795
# Coverage probability: 0.9299363057324841
# Coverage probability: 0.930379746835443
# Coverage probability: 0.9308176100628931
# Coverage probability: 0.93125
# Coverage probability: 0.9316770186335404
# Coverage probability not in the intervals
# Coverage probability: 0.9263803680981595
# Coverage probability: 0.926829268292683
# Coverage probability: 0.9272727272727272
# Coverage probability: 0.927710843373494
# Coverage probability: 0.9281437125748503
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9289940828402367
# Coverage probability: 0.9294117647058824
# Coverage probability: 0.9298245614035088
# Coverage probability: 0.9302325581395349
# Coverage probability: 0.930635838150289
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9314285714285714
# Coverage probability: 0.9318181818181818
# Coverage probability: 0.9322033898305084
# Coverage probability: 0.9325842696629213
# Coverage probability: 0.9329608938547486
# Coverage probability: 0.9333333333333333
# Coverage probability not in the intervals
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9289617486338798
# Coverage probability: 0.9293478260869565
# Coverage probability not in the intervals
# Coverage probability: 0.9247311827956989
# Coverage probability: 0.9251336898395722
# Coverage probability: 0.925531914893617
# Coverage probability: 0.9259259259259259
# Coverage probability: 0.9263157894736842
# Coverage probability not in the intervals
# Coverage probability: 0.921875
# Coverage probability: 0.9222797927461139
# Coverage probability: 0.9226804123711341
# Coverage probability: 0.9230769230769231
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9141414141414141
# Coverage probability: 0.914572864321608
# Coverage probability: 0.915
# Coverage probability: 0.9154228855721394
# Coverage probability: 0.9158415841584159
# Coverage probability: 0.916256157635468
# Coverage probability: 0.9166666666666666
# Coverage probability: 0.9170731707317074
# Coverage probability: 0.9174757281553398
# Coverage probability: 0.9178743961352657
# Coverage probability: 0.9182692307692307
# Coverage probability: 0.9186602870813397
# Coverage probability: 0.919047619047619
# Coverage probability: 0.919431279620853
# Coverage probability: 0.9198113207547169
# Coverage probability: 0.92018779342723
# Coverage probability: 0.9205607476635514
# Coverage probability: 0.9209302325581395
# Coverage probability not in the intervals
# Coverage probability: 0.9170506912442397
# Coverage probability: 0.9174311926605505
# Coverage probability: 0.9178082191780822
# Coverage probability: 0.9181818181818182
# Coverage probability: 0.918552036199095
# Coverage probability: 0.918918918918919
# Coverage probability: 0.9192825112107623
# Coverage probability: 0.9196428571428571
# Coverage probability: 0.92
# Coverage probability: 0.9203539823008849
# Coverage probability: 0.920704845814978
# Coverage probability: 0.9210526315789473
# Coverage probability: 0.9213973799126638
# Coverage probability not in the intervals
# Coverage probability: 0.9177489177489178
# Coverage probability: 0.9181034482758621
# Coverage probability: 0.9184549356223176
# Coverage probability: 0.9188034188034188
# Coverage probability: 0.9191489361702128
# Coverage probability: 0.9194915254237288
# Coverage probability: 0.919831223628692
# Coverage probability: 0.9201680672268907
# Coverage probability: 0.9205020920502092
# Coverage probability: 0.9208333333333333
# Coverage probability: 0.921161825726141
# Coverage probability: 0.9214876033057852
# Coverage probability: 0.9218106995884774
# Coverage probability: 0.9221311475409836
# Coverage probability not in the intervals
# Coverage probability: 0.9186991869918699
# Coverage probability: 0.9190283400809717
# Coverage probability: 0.9193548387096774
# Coverage probability: 0.9196787148594378
# Coverage probability: 0.92
# Coverage probability: 0.9203187250996016
# Coverage probability: 0.9206349206349206
# Coverage probability: 0.9209486166007905
# Coverage probability: 0.9212598425196851
# Coverage probability: 0.9215686274509803
# Coverage probability: 0.921875
# Coverage probability: 0.9221789883268483
# Coverage probability: 0.9224806201550387
# Coverage probability: 0.9227799227799228
# Coverage probability: 0.9230769230769231
# Coverage probability: 0.9233716475095786
# Coverage probability: 0.9236641221374046
# Coverage probability: 0.9239543726235742
# Coverage probability: 0.9242424242424242
# Coverage probability: 0.9245283018867925
# Coverage probability: 0.924812030075188
# Coverage probability: 0.9250936329588015
# Coverage probability: 0.9253731343283582
# Coverage probability: 0.9256505576208178
# Coverage probability: 0.9259259259259259
# Coverage probability: 0.9261992619926199
# Coverage probability: 0.9264705882352942
# Coverage probability: 0.9267399267399268
# Coverage probability: 0.927007299270073
# Coverage probability: 0.9272727272727272
# Coverage probability: 0.927536231884058
# Coverage probability not in the intervals
# Coverage probability: 0.9244604316546763
# Coverage probability: 0.9247311827956989
# Coverage probability: 0.925
# Coverage probability: 0.9252669039145908
# Coverage probability: 0.925531914893617
# Coverage probability: 0.9257950530035336
# Coverage probability: 0.926056338028169
# Coverage probability: 0.9263157894736842
# Coverage probability: 0.9265734265734266
# Coverage probability: 0.926829268292683
# Coverage probability: 0.9270833333333334
# Coverage probability: 0.9273356401384083
# Coverage probability: 0.9275862068965517
# Coverage probability: 0.9278350515463918
# Coverage probability: 0.928082191780822
# Coverage probability: 0.9283276450511946
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9288135593220339
# Coverage probability: 0.9290540540540541
# Coverage probability: 0.9292929292929293
# Coverage probability: 0.9295302013422819
# Coverage probability: 0.9297658862876255
# Coverage probability: 0.93
# Coverage probability: 0.9302325581395349
# Coverage probability not in the intervals
# Coverage probability: 0.9273927392739274
# Coverage probability: 0.9276315789473685
# Coverage probability: 0.9278688524590164
# Coverage probability: 0.9281045751633987
# Coverage probability: 0.9283387622149837
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9288025889967637
# Coverage probability: 0.9290322580645162
# Coverage probability: 0.9292604501607717
# Coverage probability: 0.9294871794871795
# Coverage probability: 0.9297124600638977
# Coverage probability: 0.9299363057324841
# Coverage probability: 0.9301587301587302
# Coverage probability: 0.930379746835443
# Coverage probability: 0.9305993690851735
# Coverage probability: 0.9308176100628931
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.93125
# Coverage probability not in the intervals
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287925696594427
# Coverage probability: 0.9290123456790124
# Coverage probability: 0.9292307692307692
# Coverage probability: 0.9294478527607362
# Coverage probability: 0.9296636085626911
# Coverage probability: 0.9298780487804879
# Coverage probability: 0.9300911854103343
# Coverage probability: 0.9303030303030303
# Coverage probability not in the intervals
# Coverage probability: 0.927710843373494
# Coverage probability: 0.9279279279279279
# Coverage probability: 0.9281437125748503
# Coverage probability: 0.9283582089552239
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287833827893175
# Coverage probability not in the intervals
# Coverage probability: 0.9262536873156342
# Coverage probability: 0.9264705882352942
# Coverage probability: 0.9266862170087976
# Coverage probability: 0.9269005847953217
# Coverage probability: 0.9271137026239067
# Coverage probability: 0.9273255813953488
# Coverage probability: 0.927536231884058
# Coverage probability: 0.9277456647398844
# Coverage probability: 0.9279538904899135
# Coverage probability: 0.9281609195402298
# Coverage probability: 0.9283667621776505
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287749287749287
# Coverage probability: 0.9289772727272727
# Coverage probability: 0.9291784702549575
# Coverage probability: 0.9293785310734464
# Coverage probability: 0.9295774647887324
# Coverage probability: 0.9297752808988764
# Coverage probability: 0.9299719887955182
# Coverage probability: 0.9301675977653632
# Coverage probability: 0.9303621169916435
# Coverage probability not in the intervals
# Coverage probability: 0.9279778393351801
# Coverage probability: 0.9281767955801105
# Coverage probability: 0.928374655647383
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287671232876712
# Coverage probability: 0.9289617486338798
# Coverage probability: 0.9291553133514986
# Coverage probability: 0.9293478260869565
# Coverage probability: 0.9295392953929539
# Coverage probability: 0.9297297297297298
# Coverage probability not in the intervals
# Coverage probability: 0.9274193548387096
# Coverage probability: 0.9276139410187667
# Coverage probability: 0.9278074866310161
# Coverage probability: 0.928
# Coverage probability not in the intervals
# Coverage probability: 0.9257294429708223
# Coverage probability: 0.9259259259259259
# Coverage probability: 0.9261213720316622
# Coverage probability: 0.9263157894736842
# Coverage probability: 0.926509186351706
# Coverage probability: 0.9267015706806283
# Coverage probability: 0.9268929503916449
# Coverage probability: 0.9270833333333334
# Coverage probability: 0.9272727272727272
# Coverage probability: 0.927461139896373
# Coverage probability: 0.9276485788113695
# Coverage probability: 0.9278350515463918
# Coverage probability: 0.9280205655526992
# Coverage probability: 0.9282051282051282
# Coverage probability: 0.928388746803069
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287531806615776
# Coverage probability: 0.9289340101522843
# Coverage probability: 0.9291139240506329
# Coverage probability: 0.9292929292929293
# Coverage probability: 0.929471032745592
# Coverage probability: 0.9296482412060302
# Coverage probability: 0.9298245614035088
# Coverage probability: 0.93
# Coverage probability: 0.9301745635910225
# Coverage probability not in the intervals
# Coverage probability: 0.9280397022332506
# Coverage probability: 0.9282178217821783
# Coverage probability: 0.928395061728395
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287469287469288
# Coverage probability: 0.928921568627451
# Coverage probability: 0.9290953545232273
# Coverage probability: 0.9292682926829269
# Coverage probability: 0.9294403892944039
# Coverage probability: 0.9296116504854369
# Coverage probability: 0.9297820823244553
# Coverage probability: 0.9299516908212561
# Coverage probability: 0.9301204819277108
# Coverage probability: 0.9302884615384616
# Coverage probability: 0.9304556354916067
# Coverage probability: 0.930622009569378
# Coverage probability: 0.9307875894988067
# Coverage probability: 0.930952380952381
# Coverage probability: 0.9311163895486936
# Coverage probability: 0.9312796208530806
# Coverage probability: 0.9314420803782506
# Coverage probability: 0.9316037735849056
# Coverage probability not in the intervals
# Coverage probability: 0.9295774647887324
# Coverage probability: 0.9297423887587822
# Coverage probability: 0.9299065420560748
# Coverage probability: 0.9300699300699301
# Coverage probability: 0.9302325581395349
# Coverage probability: 0.9303944315545244
# Coverage probability: 0.9305555555555556
# Coverage probability not in the intervals
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287356321839081
# Coverage probability: 0.9288990825688074
# Coverage probability: 0.9290617848970252
# Coverage probability: 0.9292237442922374
# Coverage probability: 0.929384965831435
# Coverage probability: 0.9295454545454546
# Coverage probability: 0.9297052154195011
# Coverage probability: 0.9298642533936652
# Coverage probability not in the intervals
# Coverage probability: 0.9279279279279279
# Coverage probability: 0.9280898876404494
# Coverage probability: 0.9282511210762332
# Coverage probability: 0.9284116331096197
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287305122494433
# Coverage probability: 0.9288888888888889
# Coverage probability: 0.9290465631929047
# Coverage probability: 0.9292035398230089
# Coverage probability: 0.9293598233995585
# Coverage probability: 0.9295154185022027
# Coverage probability: 0.9296703296703297
# Coverage probability not in the intervals
# Coverage probability: 0.9277899343544858
# Coverage probability: 0.9279475982532751
# Coverage probability: 0.9281045751633987
# Coverage probability: 0.9282608695652174
# Coverage probability: 0.928416485900217
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287257019438445
# Coverage probability not in the intervals
# Coverage probability: 0.9268817204301075
# Coverage probability: 0.927038626609442
# Coverage probability: 0.9271948608137045
# Coverage probability: 0.9273504273504274
# Coverage probability: 0.9275053304904051
# Coverage probability: 0.9276595744680851
# Coverage probability: 0.9278131634819533
# Coverage probability: 0.9279661016949152
# Coverage probability: 0.9281183932346723
# Coverage probability: 0.9282700421940928
# Coverage probability: 0.9284210526315789
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287211740041929
# Coverage probability: 0.9288702928870293
# Coverage probability: 0.9290187891440501
# Coverage probability: 0.9291666666666667
# Coverage probability: 0.9293139293139293
# Coverage probability: 0.9294605809128631
# Coverage probability: 0.9296066252587992
# Coverage probability: 0.9297520661157025
# Coverage probability: 0.9298969072164949
# Coverage probability: 0.9300411522633745
# Coverage probability: 0.9301848049281314
# Coverage probability: 0.930327868852459
# Coverage probability: 0.9304703476482618
# Coverage probability: 0.9306122448979591
# Coverage probability: 0.9307535641547862
# Coverage probability: 0.9308943089430894
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9311740890688259
# Coverage probability not in the intervals
# Coverage probability: 0.9294354838709677
# Coverage probability: 0.9295774647887324
# Coverage probability: 0.929718875502008
# Coverage probability: 0.9298597194388778
# Coverage probability: 0.93
# Coverage probability not in the intervals
# Coverage probability: 0.9282868525896414
# Coverage probability: 0.9284294234592445
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9287128712871288
# Coverage probability: 0.9288537549407114
# Coverage probability: 0.9289940828402367
# Coverage probability: 0.9291338582677166
# Coverage probability: 0.9292730844793713
# Coverage probability: 0.9294117647058824
# Coverage probability: 0.9295499021526419
# Coverage probability: 0.9296875
# Coverage probability: 0.9298245614035088
# Coverage probability: 0.9299610894941635
# Coverage probability: 0.9300970873786408
# Coverage probability: 0.9302325581395349
# Coverage probability: 0.9303675048355899
# Coverage probability: 0.9305019305019305
# Coverage probability: 0.930635838150289
# Coverage probability: 0.9307692307692308
# Coverage probability: 0.9309021113243762
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9311663479923518
# Coverage probability: 0.9312977099236641
# Coverage probability: 0.9314285714285714
# Coverage probability: 0.9315589353612167
# Coverage probability: 0.9316888045540797
# Coverage probability: 0.9318181818181818
# Coverage probability: 0.9319470699432892
# Coverage probability: 0.9320754716981132
# Coverage probability: 0.9322033898305084
# Coverage probability: 0.9323308270676691
# Coverage probability: 0.9324577861163227
# Coverage probability: 0.9325842696629213
# Coverage probability: 0.9327102803738317
# Coverage probability: 0.9328358208955224
# Coverage probability: 0.9329608938547486
# Coverage probability: 0.9330855018587361
# Coverage probability: 0.9332096474953617
# Coverage probability: 0.9333333333333333
# Coverage probability: 0.933456561922366
# Coverage probability: 0.933579335793358
# Coverage probability: 0.9337016574585635
# Coverage probability: 0.9338235294117647
# Coverage probability: 0.9339449541284404
# Coverage probability: 0.9340659340659341
# Coverage probability: 0.9341864716636198
# Coverage probability: 0.9343065693430657
# Coverage probability: 0.9344262295081968
# Coverage probability: 0.9345454545454546
# Coverage probability: 0.9346642468239564
# Coverage probability: 0.9347826086956522
# Coverage probability: 0.9349005424954792
# Coverage probability: 0.9350180505415162
# Coverage probability not in the intervals
# Coverage probability: 0.9334532374100719
# Coverage probability: 0.933572710951526
# Coverage probability: 0.9336917562724014
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.93048128342246
# Coverage probability: 0.9306049822064056
# Coverage probability: 0.9307282415630551
# Coverage probability: 0.9308510638297872
# Coverage probability: 0.9309734513274336
# Coverage probability: 0.931095406360424
# Coverage probability: 0.9312169312169312
# Coverage probability: 0.9313380281690141
# Coverage probability: 0.9314586994727593
# Coverage probability: 0.9315789473684211
# Coverage probability: 0.9316987740805605
# Coverage probability: 0.9318181818181818
# Coverage probability: 0.9319371727748691
# Coverage probability: 0.9320557491289199
# Coverage probability: 0.9321739130434783
# Coverage probability: 0.9322916666666666
# Coverage probability: 0.9324090121317158
# Coverage probability: 0.9325259515570934
# Coverage probability: 0.9326424870466321
# Coverage probability: 0.9327586206896552
# Coverage probability: 0.9328743545611016
# Coverage probability: 0.9329896907216495
# Coverage probability: 0.9331046312178388
# Coverage probability: 0.9332191780821918
# Coverage probability: 0.9333333333333333
# Coverage probability: 0.9334470989761092
# Coverage probability: 0.9335604770017035
# Coverage probability: 0.9336734693877551
# Coverage probability: 0.933786078098472
# Coverage probability: 0.9338983050847458
# Coverage probability: 0.934010152284264
# Coverage probability: 0.9341216216216216
# Coverage probability not in the intervals
# Coverage probability: 0.9326599326599326
# Coverage probability: 0.9327731092436975
# Coverage probability not in the intervals
# Coverage probability: 0.931323283082077
# Coverage probability: 0.931438127090301
# Coverage probability not in the intervals
# Coverage probability: 0.93
# Coverage probability: 0.930116472545757
# Coverage probability: 0.9302325581395349
# Coverage probability: 0.9303482587064676
# Coverage probability: 0.9304635761589404
# Coverage probability: 0.9305785123966942
# Coverage probability: 0.9306930693069307
# Coverage probability: 0.9308072487644151
# Coverage probability: 0.930921052631579
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9311475409836065
# Coverage probability: 0.9312602291325696
# Coverage probability: 0.9313725490196079
# Coverage probability: 0.9314845024469821
# Coverage probability: 0.9315960912052117
# Coverage probability: 0.9317073170731708
# Coverage probability: 0.9318181818181818
# Coverage probability not in the intervals
# Coverage probability: 0.93042071197411
# Coverage probability: 0.9305331179321487
# Coverage probability: 0.9306451612903226
# Coverage probability: 0.9307568438003221
# Coverage probability: 0.9308681672025724
# Coverage probability: 0.9309791332263242
# Coverage probability: 0.9310897435897436
# Coverage probability: 0.9312
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.928343949044586
# Coverage probability: 0.9284578696343402
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9286846275752774
# Coverage probability: 0.9287974683544303
# Coverage probability: 0.9289099526066351
# Coverage probability: 0.9290220820189274
# Coverage probability not in the intervals
# Coverage probability: 0.9276729559748428
# Coverage probability: 0.9277864992150706
# Coverage probability: 0.9278996865203761
# Coverage probability: 0.9280125195618153
# Coverage probability: 0.928125
# Coverage probability: 0.9282371294851794
# Coverage probability: 0.9283489096573209
# Coverage probability: 0.9284603421461898
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9286821705426357
# Coverage probability: 0.9287925696594427
# Coverage probability: 0.9289026275115919
# Coverage probability: 0.9290123456790124
# Coverage probability: 0.9291217257318952
# Coverage probability: 0.9292307692307692
# Coverage probability: 0.9293394777265745
# Coverage probability: 0.9294478527607362
# Coverage probability: 0.9295558958652373
# Coverage probability: 0.9296636085626911
# Coverage probability: 0.9297709923664123
# Coverage probability: 0.9298780487804879
# Coverage probability: 0.9299847792998478
# Coverage probability: 0.9300911854103343
# Coverage probability: 0.9301972685887708
# Coverage probability: 0.9303030303030303
# Coverage probability: 0.9304084720121029
# Coverage probability: 0.9305135951661632
# Coverage probability: 0.9306184012066365
# Coverage probability: 0.9307228915662651
# Coverage probability: 0.9308270676691729
# Coverage probability: 0.9309309309309309
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9311377245508982
# Coverage probability: 0.9312406576980568
# Coverage probability not in the intervals
# Coverage probability: 0.9299552906110283
# Coverage probability not in the intervals
# Coverage probability: 0.9286775631500743
# Coverage probability: 0.9287833827893175
# Coverage probability: 0.9288888888888889
# Coverage probability: 0.9289940828402367
# Coverage probability: 0.9290989660265879
# Coverage probability: 0.9292035398230089
# Coverage probability: 0.9293078055964654
# Coverage probability: 0.9294117647058824
# Coverage probability: 0.9295154185022027
# Coverage probability: 0.9296187683284457
# Coverage probability: 0.9297218155197657
# Coverage probability: 0.9298245614035088
# Coverage probability: 0.92992700729927
# Coverage probability: 0.9300291545189504
# Coverage probability: 0.9301310043668122
# Coverage probability: 0.9302325581395349
# Coverage probability: 0.93033381712627
# Coverage probability: 0.9304347826086956
# Coverage probability: 0.9305354558610709
# Coverage probability: 0.930635838150289
# Coverage probability not in the intervals
# Coverage probability: 0.9293948126801153
# Coverage probability: 0.9294964028776979
# Coverage probability: 0.9295977011494253
# Coverage probability: 0.9296987087517934
# Coverage probability: 0.9297994269340975
# Coverage probability: 0.9298998569384835
# Coverage probability: 0.93
# Coverage probability: 0.9300998573466477
# Coverage probability: 0.9301994301994302
# Coverage probability: 0.930298719772404
# Coverage probability: 0.9303977272727273
# Coverage probability: 0.9304964539007092
# Coverage probability: 0.9305949008498584
# Coverage probability: 0.9306930693069307
# Coverage probability: 0.9307909604519774
# Coverage probability: 0.9308885754583921
# Coverage probability: 0.9309859154929577
# Coverage probability: 0.9310829817158931
# Coverage probability: 0.9311797752808989
# Coverage probability: 0.9312762973352033
# Coverage probability: 0.9313725490196079
# Coverage probability: 0.9314685314685315
# Coverage probability: 0.9315642458100558
# Coverage probability: 0.9316596931659693
# Coverage probability: 0.9317548746518106
# Coverage probability: 0.9318497913769124
# Coverage probability: 0.9319444444444445
# Coverage probability: 0.9320388349514563
# Coverage probability: 0.9321329639889196
# Coverage probability: 0.9322268326417704
# Coverage probability: 0.9323204419889503
# Coverage probability: 0.9324137931034483
# Coverage probability: 0.9325068870523416
# Coverage probability: 0.9325997248968363
# Coverage probability: 0.9326923076923077
# Coverage probability: 0.9327846364883402
# Coverage probability: 0.9328767123287671
# Coverage probability not in the intervals
# Coverage probability: 0.9316939890710383
# Coverage probability: 0.931787175989086
# Coverage probability: 0.9318801089918256
# Coverage probability: 0.9319727891156463
# Coverage probability: 0.9320652173913043
# Coverage probability: 0.932157394843962
# Coverage probability: 0.9322493224932249
# Coverage probability: 0.93234100135318
# Coverage probability: 0.9324324324324325
# Coverage probability: 0.9325236167341431
# Coverage probability not in the intervals
# Coverage probability: 0.9313593539703903
# Coverage probability: 0.9314516129032258
# Coverage probability: 0.9315436241610738
# Coverage probability: 0.9316353887399463
# Coverage probability: 0.9317269076305221
# Coverage probability: 0.9318181818181818
# Coverage probability: 0.931909212283044
# Coverage probability: 0.932
# Coverage probability: 0.9320905459387483
# Coverage probability: 0.9321808510638298
# Coverage probability: 0.9322709163346613
# Coverage probability: 0.9323607427055703
# Coverage probability: 0.9324503311258279
# Coverage probability: 0.9325396825396826
# Coverage probability: 0.9326287978863936
# Coverage probability not in the intervals
# Coverage probability: 0.9314888010540184
# Coverage probability: 0.9315789473684211
# Coverage probability not in the intervals
# Coverage probability: 0.9304461942257218
# Coverage probability not in the intervals
# Coverage probability: 0.9293193717277487
# Coverage probability: 0.9294117647058824
# Coverage probability: 0.9295039164490861
# Coverage probability: 0.9295958279009127
# Coverage probability: 0.9296875
# Coverage probability: 0.929778933680104
# Coverage probability: 0.9298701298701298
# Coverage probability: 0.9299610894941635
# Coverage probability: 0.9300518134715026
# Coverage probability not in the intervals
# Coverage probability: 0.9289405684754521
# Coverage probability: 0.9290322580645162
# Coverage probability: 0.9291237113402062
# Coverage probability: 0.9292149292149292
# Coverage probability: 0.929305912596401
# Coverage probability: 0.9293966623876765
# Coverage probability: 0.9294871794871795
# Coverage probability: 0.9295774647887324
# Coverage probability: 0.9296675191815856
# Coverage probability: 0.929757343550447
# Coverage probability: 0.9298469387755102
# Coverage probability: 0.9299363057324841
# Coverage probability: 0.9300254452926209
# Coverage probability: 0.9301143583227446
# Coverage probability: 0.9302030456852792
# Coverage probability: 0.9302915082382763
# Coverage probability: 0.930379746835443
# Coverage probability: 0.9304677623261695
# Coverage probability not in the intervals
# Coverage probability: 0.9293820933165196
# Coverage probability: 0.929471032745592
# Coverage probability not in the intervals
# Coverage probability: 0.928391959798995
# Coverage probability not in the intervals
# Coverage probability: 0.9273182957393483
# Coverage probability: 0.9274092615769712
# Coverage probability: 0.9275
# Coverage probability: 0.9275905118601748
# Coverage probability not in the intervals
# Coverage probability: 0.9265255292652553
# Coverage probability: 0.9266169154228856
# Coverage probability: 0.9267080745341615
# Coverage probability: 0.9267990074441688
# Coverage probability: 0.9268897149938042
# Coverage probability: 0.926980198019802
# Coverage probability: 0.927070457354759
# Coverage probability: 0.9271604938271605
# Coverage probability: 0.9272503082614056
# Coverage probability not in the intervals
# Coverage probability: 0.9261992619926199
# Coverage probability: 0.9262899262899262
# Coverage probability: 0.9263803680981595
# Coverage probability: 0.9264705882352942
# Coverage probability: 0.9265605875152999
# Coverage probability: 0.9266503667481663
# Coverage probability: 0.9267399267399268
# Coverage probability: 0.926829268292683
# Coverage probability: 0.9269183922046285
# Coverage probability: 0.927007299270073
# Coverage probability: 0.9270959902794653
# Coverage probability: 0.9271844660194175
# Coverage probability: 0.9272727272727272
# Coverage probability not in the intervals
# Coverage probability: 0.9262394195888755
# Coverage probability: 0.9263285024154589
# Coverage probability: 0.9264173703256936
# Coverage probability: 0.9265060240963855
# Coverage probability: 0.9265944645006017
# Coverage probability: 0.9266826923076923
# Coverage probability: 0.9267707082833133
# Coverage probability: 0.9268585131894485
# Coverage probability: 0.9269461077844311
# Coverage probability: 0.9270334928229665
# Coverage probability: 0.927120669056153
# Coverage probability: 0.9272076372315036
# Coverage probability: 0.9272943980929678
# Coverage probability: 0.9273809523809524
# Coverage probability: 0.9274673008323424
# Coverage probability: 0.9275534441805225
# Coverage probability not in the intervals
# Coverage probability: 0.9265402843601895
# Coverage probability: 0.9266272189349113
# Coverage probability: 0.9267139479905437
# Coverage probability: 0.9268004722550177
# Coverage probability: 0.9268867924528302
# Coverage probability: 0.9269729093050648
# Coverage probability: 0.9270588235294117
# Coverage probability: 0.927144535840188
# Coverage probability not in the intervals
# Coverage probability: 0.9261430246189918
# Coverage probability: 0.9262295081967213
# Coverage probability: 0.9263157894736842
# Coverage probability not in the intervals
# Coverage probability: 0.9253208868144691
# Coverage probability: 0.9254079254079254
# Coverage probability: 0.9254947613504074
# Coverage probability: 0.9255813953488372
# Coverage probability: 0.9256678281068524
# Coverage probability: 0.925754060324826
# Coverage probability not in the intervals
# Coverage probability: 0.9247685185185185
# Coverage probability: 0.9248554913294798
# Coverage probability: 0.9249422632794457
# Coverage probability: 0.9250288350634371
# Coverage probability: 0.9251152073732719
# Coverage probability: 0.9252013808975834
# Coverage probability: 0.9252873563218391
# Coverage probability: 0.9253731343283582
# Coverage probability: 0.9254587155963303
# Coverage probability: 0.9255441008018328
# Coverage probability: 0.9256292906178489
# Coverage probability: 0.9257142857142857
# Coverage probability: 0.9257990867579908
# Coverage probability: 0.9258836944127709
# Coverage probability: 0.9259681093394078
# Coverage probability: 0.926052332195677
# Coverage probability: 0.9261363636363636
# Coverage probability: 0.9262202043132803
# Coverage probability: 0.9263038548752834
# Coverage probability not in the intervals
# Coverage probability: 0.9253393665158371
# Coverage probability: 0.9254237288135593
# Coverage probability: 0.9255079006772009
# Coverage probability: 0.9255918827508456
# Coverage probability: 0.9256756756756757
# Coverage probability: 0.9257592800899888
# Coverage probability: 0.9258426966292135
# Coverage probability: 0.9259259259259259
# Coverage probability: 0.9260089686098655
# Coverage probability: 0.9260918253079508
# Coverage probability: 0.9261744966442953
# Coverage probability: 0.9262569832402234
# Coverage probability: 0.9263392857142857
# Coverage probability: 0.9264214046822743
# Coverage probability: 0.9265033407572383
# Coverage probability: 0.9265850945494994
# Coverage probability: 0.9266666666666666
# Coverage probability: 0.9267480577136515
# Coverage probability: 0.926829268292683
# Coverage probability: 0.9269102990033222
# Coverage probability: 0.9269911504424779
# Coverage probability: 0.9270718232044199
# Coverage probability: 0.9271523178807947
# Coverage probability: 0.9272326350606395
# Coverage probability: 0.9273127753303965
# Coverage probability: 0.9273927392739274
# Coverage probability: 0.9274725274725275
# Coverage probability: 0.9275521405049396
# Coverage probability: 0.9276315789473685
# Coverage probability: 0.927710843373494
# Coverage probability: 0.9277899343544858
# Coverage probability: 0.9278688524590164
# Coverage probability: 0.9279475982532751
# Coverage probability not in the intervals
# Coverage probability: 0.9270152505446623
# Coverage probability: 0.9270946681175191
# Coverage probability: 0.9271739130434783
# Coverage probability: 0.9272529858849077
# Coverage probability: 0.9273318872017353
# Coverage probability: 0.9274106175514626
# Coverage probability: 0.9274891774891775
# Coverage probability: 0.9275675675675675
# Coverage probability: 0.927645788336933
# Coverage probability: 0.9277238403451996
# Coverage probability: 0.927801724137931
# Coverage probability: 0.9278794402583423
# Coverage probability: 0.9279569892473118
# Coverage probability: 0.9280343716433942
# Coverage probability: 0.9281115879828327
# Coverage probability: 0.9281886387995713
# Coverage probability: 0.9282655246252677
# Coverage probability: 0.9283422459893048
# Coverage probability: 0.9284188034188035
# Coverage probability: 0.928495197438634
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9286474973375932
# Coverage probability: 0.9287234042553192
# Coverage probability: 0.9287991498405951
# Coverage probability: 0.9288747346072187
# Coverage probability: 0.9289501590668081
# Coverage probability: 0.9290254237288136
# Coverage probability: 0.9291005291005291
# Coverage probability: 0.9291754756871036
# Coverage probability: 0.9292502639915523
# Coverage probability: 0.929324894514768
# Coverage probability: 0.9293993677555321
# Coverage probability: 0.9294736842105263
# Coverage probability not in the intervals
# Coverage probability: 0.9285714285714286
# Coverage probability: 0.9286463798530955
# Coverage probability: 0.9287211740041929
# Coverage probability: 0.9287958115183246
# Coverage probability: 0.9288702928870293
# Coverage probability: 0.928944618599791
# Coverage probability: 0.9290187891440501
# Coverage probability: 0.9290928050052137
# Coverage probability: 0.9291666666666667
# Coverage probability: 0.9292403746097815
# Coverage probability: 0.9293139293139293
# Coverage probability: 0.9293873312564901
# Coverage probability: 0.9294605809128631
# Coverage probability: 0.9295336787564766
# Coverage probability: 0.9296066252587992
# Coverage probability: 0.9296794208893485
# Coverage probability: 0.9297520661157025
# Coverage probability: 0.9298245614035088
# Coverage probability: 0.9298969072164949
# Coverage probability: 0.9299691040164778
# Coverage probability: 0.9300411522633745
# Coverage probability: 0.9301130524152107
# Coverage probability: 0.9301848049281314
# Coverage probability: 0.9302564102564103
# Coverage probability: 0.930327868852459
# Coverage probability: 0.9303991811668373
# Coverage probability: 0.9304703476482618
# Coverage probability: 0.9305413687436159
# Coverage probability: 0.9306122448979591
# Coverage probability: 0.9306829765545361
# Coverage probability: 0.9307535641547862
# Coverage probability: 0.930824008138352
# Coverage probability: 0.9308943089430894
# Coverage probability: 0.9309644670050762
# Coverage probability: 0.9310344827586207
# Coverage probability: 0.9311043566362716
# Coverage probability: 0.9311740890688259
# Coverage probability: 0.9312436804853387
# Coverage probability: 0.9313131313131313
# Coverage probability not in the intervals
# Coverage probability: 0.9304435483870968
# Coverage probability: 0.9305135951661632
# Coverage probability: 0.9305835010060363
# Coverage probability: 0.9306532663316583
# Coverage probability: 0.9307228915662651
# Coverage probability: 0.9307923771313942
# Coverage probability: 0.9308617234468938
# Coverage probability: 0.9309309309309309
# Coverage probability: 0.931
