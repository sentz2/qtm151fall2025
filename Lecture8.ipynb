# %% [markdown]
# # <span style="color:red"> Lecture 8: Application - Simulating Random Variables </span>

# %% [markdown]
# <font size="5">
#
# In this class we will:
#
# - Use loops within an actual context: simulating random variables
# - Notebook also contains

# %% [markdown]
# ## <span style="color:red"> I. Import Libraries </span>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:red"> II. Visualizing Random Variables </span>

# %% [markdown]
# <font size = "5" >
#
# Consider a sample with $n$ observations
#
# $ X = \begin{pmatrix} X_1 \\ X_2 \\ \vdots \\ X_n \end{pmatrix}.$

# %% [markdown]
# <font size = "5" > We can simulate from different probability distributions. Some common ones are:
#
# - The normal distribution with mean $\mu$ and standard deviation (s.d.) $\sigma$
#     - The **standard** normal distribution has mean $\mu = 0$ and s.d. $\sigma = 1$
# - The $\chi^2$-distribution ("chi-squared") with $k$ degrees of freedom.
#     - If you take $k$ standard normal samples and add up their squares, you get a single sample from a chi-squared distribution with $k$ degrees of freedom.
# - The uniform distribution with endpoints $a < b$.

# %%
# Set sample size
n = 10000

# Draw n samples from normal distribution with mean = -2, s.d. = 6
normal_samples = np.random.normal(loc = -2, scale = 6, size = n)

# Draw n samples from chi-squared distribution with 4 degrees of freedom
chisqr_samples = np.random.chisquare(df = 4, size = n)

# Draw n samples from uniform distribution with a = -3, b = 5
unif_samples = np.random.uniform(low = -3, high = 5, size = n)

# %%
# np.random.normal and np.random.uniform have some default inputs

# Draw n samples from standard normal distribution (mean = 0, s.d. = 1)
# Default: loc = 0
# Default: scale = 1
std_normal_samples = np.random.normal(size = n)

# Draw n samples from uniform distribution over unit interval (a = 0, b = 1)
# Default: low = 0
# Default: high = 1
unit_unif_samples = np.random.uniform(size = n)

# %% [markdown]
# <font size = "5">
#
# The sample average is defined as
#
# $$ \bar{X} = \frac{1}{n}\sum_{i=1}^n X_i $$

# %%
# Let's print of each of the above random variables

print(normal_samples.mean())
print(chisqr_samples.mean())
print(unif_samples.mean())
print(std_normal_samples.mean())
print(unit_unif_samples.mean())
# Out:
# -2.013703037206663
# 4.00838228068189
# 1.0008828468355895
# -0.009961236658909309
# 0.5043481080631318

# %%
# Could also do:
print(np.mean(normal_samples))
print(np.mean(chisqr_samples))
print(np.mean(unif_samples))
print(np.mean(std_normal_samples))
print(np.mean(unit_unif_samples))
# Out:
# -2.013703037206663
# 4.00838228068189
# 1.0008828468355895
# -0.009961236658909309
# 0.5043481080631318

# %%
# each distribution has an expected value (theoretical mean)
print("Theoretical mean for normal_samples: ", -2)
print("Theoretical mean for chisqr_samples: ", 4)
print("Theoretical mean for unif_samples: ", 1)
print("Theoretical mean for std_normal_samples: ", 0)
print("Theoretical mean for unit_unif_samples: ", 0.5)
# Out:
# Theoretical mean for normal_samples:  -2
# Theoretical mean for chisqr_samples:  4
# Theoretical mean for unif_samples:  1
# Theoretical mean for std_normal_samples:  0
# Theoretical mean for unit_unif_samples:  0.5

# %% [markdown]
# <font size = "5" >
#
# Multiple plots in a row (subplot)
#
# - The probability density function (pdf) of the normal distribution has a bell shape
# - The pdf of the uniform distribution has a rectangular shape
# - We can make an **approximate** plot of the pdf by creating a histogram of the generated samples

# %%
#------------------------ Setting up subplots----------------------------------#
# Create a plot with 1 row, 2 columns
# First, create a "matplotlib Figure" and an array of "sub-figures"

fig, subfig_array = plt.subplots(nrows = 1, ncols = 2,figsize = (6,3))

# plt.subplots has TWO outputs, so we assign the output to TWO variables
# The names we give them are OUR CHOICE
# The option "figsize" indicates the (width,height)) of the graph.
# The complete figure will be 6 inches wide, 3 inches tall


# First Sub-Figure
subfig_array[0].hist(x = normal_samples)
subfig_array[0].set_title("Normal Distribution\n with mean -2, s.d. 6")
subfig_array[0].set_xlabel("Sample Value")
subfig_array[0].set_ylabel("Frequency")

# Second Figure
subfig_array[1].hist(x = unif_samples)
subfig_array[1].set_title("Uniform Distribution\n over [-3, 5]")
subfig_array[1].set_xlabel("Sample Value")
subfig_array[1].set_ylabel("Frequency")

# The tight layout option ensures that the axes are not overlapping
# plt.tight_layout()


plt.show()

# %% [markdown]
# <font size = "5">
#
# Now, let's do a version with three plots in the same row. We'll add the histogram of the chi-squared samples too

# %%
fig, subfig_array = plt.subplots(1, 3, figsize = (9,3))

# First sub-figure
subfig_array[0].hist(x = normal_samples)
subfig_array[0].set_title("Normal Distribution\n with mean -2, s.d. 6")
subfig_array[0].set_xlabel("Sample Value")
subfig_array[0].set_ylabel("Frequency")

# Second sub-figure
subfig_array[1].hist(x = unif_samples)
subfig_array[1].set_title("Uniform Distribution\n over [-3, 5]")
subfig_array[1].set_xlabel("Sample Value")
subfig_array[1].set_ylabel("Frequency")

# Third sub-figure
subfig_array[2].hist(x = chisqr_samples)
subfig_array[2].set_title("Chi Square Distribution\n with 4 degrees of freedom")
subfig_array[2].set_xlabel("Sample Value")
subfig_array[2].set_ylabel("Frequency")

# The tight layout option ensures that the axes are not overlapping
plt.tight_layout()

# %% [markdown]
# <font size = "5">
#
# - Now we make a figure with 4 plots arranged in a 2x2 pattern
# - Compare standard normal with our normal
# - Compare uniform over [0, 1] with uniform over [-3,5]

# %%
fig, subfig_array = plt.subplots(2, 2, figsize = (6,6))

# First sub-figure
subfig_array[0,0].hist(x = normal_samples)
subfig_array[0,0].set_title("Normal Distribution\n with mean -2, s.d. 6")
subfig_array[0,0].set_xlabel("Sample Value")
subfig_array[0,0].set_ylabel("Frequency")

# second sub-figure
subfig_array[0,1].hist(x = std_normal_samples)
subfig_array[0,1].set_title("Normal Distribution\n with mean 0, s.d. 1")
subfig_array[0,1].set_xlabel("Sample Value")
subfig_array[0,1].set_ylabel("Frequency")

# third sub-figure
subfig_array[1,0].hist(x = unif_samples)
subfig_array[1,0].set_title("Uniform Distribution\n over [-3, 5]")
subfig_array[1,0].set_xlabel("Sample Value")
subfig_array[1,0].set_ylabel("Frequency")


# fourth sub-figure
subfig_array[1,1].hist(x = unit_unif_samples)
subfig_array[1,1].set_title("Uniform Distribution\n over [0, 1]")
subfig_array[1,1].set_xlabel("Sample Value")
subfig_array[1,1].set_ylabel("Frequency")

# The tight layout option ensures that the axes are not overlapping
plt.tight_layout()

# %% [markdown]
# ## <span style="color:red"> III. Single Loops </span>

# %% [markdown]
# <font size = "5">
#
# How does $\bar{X}$ change over different samples of the same size?

# %%
# store sample mean in a list
list_xbar = [None, None, None, None]
sample_size = 100

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[0] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[1] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[2] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
list_xbar[3] = vec_unif.mean()

print(list_xbar)
print()
print(np.array(list_xbar))
print("Theoretical mean: ", 0)
# Out:
# [np.float64(0.08096400778097683), np.float64(0.11917037963249996), np.float64(0.11887095710103872), np.float64(-0.32620570971801827)]
#
# [ 0.08096401  0.11917038  0.11887096 -0.32620571]
# Theoretical mean:  0

# %%
# store sample mean in a numpy array (vector)
# vec_xbar = np.array([None, None, None, None])

# starting with zeros is more simple than starting with "None"
vec_xbar = np.zeros(4)


sample_size = 100

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[0] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[1] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[2] = vec_unif.mean()

vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[3] = vec_unif.mean()

print(vec_xbar)
print("Theoretical mean: ", 0)
# Out:
# [ 0.05218545 -0.01778846 -0.02018467 -0.03270054]
# Theoretical mean:  0

# %%
# We will draw random sample "num_simulations" times
# Each time we will create a random vector of size "sample_size"
# In this example we will generate values from a uniform between -2 and 2.

num_simulations = 2000
sample_size     = 100

# using an array starting with zeros
vec_xbar = np.zeros(num_simulations)

# or array filled with None
# vec_xbar = np.full(num_simulations, None, dtype=object)

# using a list
list_xbar = [None] * num_simulations

for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
    list_xbar[iteration] = vec_unif.mean()


plt.hist(x = vec_xbar)
plt.title("Distribution of Xbar with different simulated samples")
plt.ylabel("Frequency")
plt.xlabel("Values of Xbar")
plt.show()

# %% [markdown]
# ## <span style="color:red"> IV. Nested Loops </span>

# %% [markdown]
# <font size = "5">
#
# What happens to $\bar{X}$ with different $n$?
#
# - The Central Limit Theorem makes a prediction!
# - It says that the distribution will have a bell shape with higher $n$.

# %%
# One way is to write this with repeated code chunks
# We just repeat the code that we had above, with different sample sizes
# Each time will start the process of generating new data from scratch.

fig, subfig_array = plt.subplots(1, 3, figsize = (9,3))

num_simulations = 2000

# Simulate with sample size one
sample_size = 1
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
subfig_array[0].hist(vec_xbar)
subfig_array[0].set_title("Distribution of Xbar with size 1")
subfig_array[0].set_ylabel("Frequency")
subfig_array[0].set_xlabel("Values of Xbar")


# Simulate with sample size 10
sample_size = 10
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
subfig_array[1].hist(vec_xbar)
subfig_array[1].set_title("Distribution of Xbar with size 10")
subfig_array[1].set_ylabel("Frequency")
subfig_array[1].set_xlabel("Values of Xbar")

# Simulate with sample size 50
sample_size = 50
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
subfig_array[2].hist(vec_xbar)
subfig_array[2].set_title("Distribution of Xbar with size 50")
subfig_array[2].set_ylabel("Frequency")
subfig_array[2].set_xlabel("Values of Xbar")

plt.tight_layout()
plt.show()

# %%
# Let's make all 3 plots have consistent x and y limits

fig, subfig_array = plt.subplots(1, 3, figsize = (9,3))

num_simulations = 2000

# Simulate with sample size one
sample_size = 1
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()


subfig_array[0].hist(vec_xbar)
subfig_array[0].set_title("Distribution of Xbar with size 1")
subfig_array[0].set_ylabel("Frequency")
subfig_array[0].set_xlabel("Values of Xbar")
subfig_array[0].set_xlim(-2,2)


# Simulate with sample size 10
sample_size = 10
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()


subfig_array[1].hist(vec_xbar)
subfig_array[1].set_title("Distribution of Xbar with size 10")
subfig_array[1].set_ylabel("Frequency")
subfig_array[1].set_xlabel("Values of Xbar")
subfig_array[1].set_xlim(-2,2)

# Simulate with sample size 50
sample_size = 50
vec_xbar = np.zeros(num_simulations)
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()


subfig_array[2].hist(vec_xbar)
subfig_array[2].set_title("Distribution of Xbar with size 50")
subfig_array[2].set_ylabel("Frequency")
subfig_array[2].set_xlabel("Values of Xbar")
subfig_array[2].set_xlim(-2,2)

subfig_array[0].set_ylim(top=525)
subfig_array[1].set_ylim(top=525)
subfig_array[2].set_ylim(top=525)

plt.tight_layout()
plt.show()

# %% [markdown]
# <font size = "5">
# Let's do with with 2 for loops, one inside the other. (Nested loops)

# %%
num_simulations = 2000
sample_size_list = [1,10,50,100,150,200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]

N = len(sample_size_list)

fig, subfig_array = plt.subplots(2, 3, figsize = (9,6))

xmin = -2
xmax = 2
ymax = 550

for k in range(N):
    sample_sz = sample_size_list[k]
    row = fig_row[k]
    col = fig_col[k]

    vec_xbar = np.zeros(num_simulations)
    for iteration in range(num_simulations):
        vec_unif  = np.random.uniform(low = -2, high=2, size = sample_sz)
        vec_xbar[iteration] = vec_unif.mean()

    subfig_array[row,col].hist(vec_xbar)
    subfig_array[row,col].set_title("Distribution of Xbar with\n sample size " + str(sample_sz))
    subfig_array[row,col].set_ylabel("Frequency")
    subfig_array[row,col].set_xlabel("Values of Xbar") 
    subfig_array[row,col].set_xlim(xmin,xmax) 
    subfig_array[row,col].set_ylim(top=ymax)  

plt.tight_layout()
plt.show()

# %% [markdown]
# <font size = "5">
# Notice that our loop variable "k" traversed the values 0, 1, 2, 3, 4, 5. But the only reason we needed these values was because we needed to access the k-th element of 3 lists.
# <br>
#
# ```python
#     sample_sz = sample_size_list[k]
#     row = fig_row[k]
#     col = fig_col[k]
# ```
#
# The only purpose of "k" was to define these 3 elements. Ideally we would like to do something like:
# <br>
#
# ```python
#     for sample_sz, row, col in something:
# ```
#
# The ``zip`` function allows us to create an appropiate object for "something"

# %%
print(zip(sample_size_list, fig_row, fig_col)) # not helpful at all..
# Out:
# <zip object at 0x1758b3980>

# %%
print(list(zip(sample_size_list, fig_row, fig_col)))
# Out:
# [(1, 0, 0), (10, 0, 1), (50, 0, 2), (100, 1, 0), (150, 1, 1), (200, 1, 2)]

# %%
num_simulations = 2000
sample_size_list = [1,10,50,100,150,200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]


fig, subfig_array = plt.subplots(2, 3, figsize = (9,6))

xmin = -2
xmax = 2
ymax = 600

for sample_sz, row, col in zip(sample_size_list, fig_row, fig_col):

    vec_xbar = np.zeros(num_simulations)
    for iteration in range(num_simulations):
        vec_unif  = np.random.uniform(low = -2, high=2, size = sample_sz)
        vec_xbar[iteration] = vec_unif.mean()

    subfig_array[row,col].hist(vec_xbar)
    subfig_array[row,col].set_title("Distribution of Xbar with\n sample size " + str(sample_sz))
    subfig_array[row,col].set_ylabel("Frequency")
    subfig_array[row,col].set_xlabel("Values of Xbar") 
    subfig_array[row,col].set_xlim(xmin,xmax) 
    subfig_array[row,col].set_ylim(top=ymax)  

plt.tight_layout()
plt.show()

# %% [markdown]
# <font size = "5">
# Try it yourself!
#
# - Repeat the above simulation with a few changes
# - Write code that puts all the figures in the same row
# - Use a Chi-square distribution with (df = 1) instead of a normal

# %%
# Write your own solution
print(list(zip(sample_size_list, fig_row, fig_col)))
sample_size_list = [5, 10, 20, 50, 100, 200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]
num_simulations = 1000

fig, subfig_array = plt.subplots(1, len(sample_size_list), figsize = (18, 3))
xmin = -2
xmax = 2
ymax = 600

for ax, sample_sz in zip(subfig_array, sample_size_list):
    vec_xbar = np.zeros(num_simulations)
    for iteration in range(num_simulations):
        vec_unif = np.random.chisquare(df=1, size = sample_sz)
        vec_xbar[iteration] = vec_unif.mean()

    ax.hist(vec_xbar, bins=30)
    ax.set_title(f"Distribution of Xbar with\n sample size {sample_sz}")
    ax.set_xlabel("Values of X")
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(top=ymax)

plt.tight_layout()
plt.show()
# Out:
# [(5, 0, 0), (10, 0, 1), (20, 0, 2), (50, 1, 0), (100, 1, 1), (200, 1, 2)]

# %% [markdown]
# ## <span style="color:red"> V. (Extra content) Loops + If/else </span>

# %% [markdown]
# <font size = "5">
#
# Let "sample_stdv" be the sample standard deviation of $X_i$.

# %%
# Parameters of a normal random variable
n                 = 10000
population_mean   = 2
population_stdv   = 5

# Create random variable and produce summary statistics
X           = np.random.normal(loc = 2,scale = 5,size = n)
Xbar        = X.mean()
sample_stdv = X.std()

# Check that the sample and standard deviation are close to their
# population values
print(Xbar)
print(sample_stdv)
# Out:
# 2.0893337981473827
# 5.0274444931127364

# %% [markdown]
# <font size = "5">
#
# A 95\% normal confidence interval is defined by $\ldots$
#
# - lower_bound = $\bar{X} -1.96 \times  \frac{\text{sample\_stdv}}{\sqrt{n}}$.
# - upper_bound = $\bar{X} + 1.96 \times \frac{\text{sample\_stdv}}{\sqrt{n}}$.

# %%
# Compute new variables for the upper and lower bound

lower_bound = Xbar - 1.96*(sample_stdv / np.sqrt(n))
upper_bound = Xbar + 1.96*(sample_stdv / np.sqrt(n))

# %% [markdown]
# <font size = "5">
# Try it yourself! Write an if/else that checks whether <br>
#
# lower_bound $\quad \le \quad $ population_mean $\quad \le \quad$ upper_bound

# %%
# Write your own code
n                 = 10000
population_mean   = 2
population_stdv   = 5
X           = np.random.normal(loc = 2,scale = 5,size = n)
Xbar        = X.mean()
sample_stdv = X.std()
lower_bound = Xbar - 1.96*(sample_stdv / np.sqrt(n))
upper_bound = Xbar + 1.96*(sample_stdv / np.sqrt(n))

if lower_bound <= population_mean <= upper_bound:
        print("Lower bound <= Population Mean <= Upper bound")
else: 
        print("Population Mean is Not in the interval")
print(lower_bound)
print(upper_bound)
print(population_mean)
# Out:
# Lower bound <= Population Mean <= Upper bound
# 1.9022078584129316
# 2.099991571243252
# 2

# %% [markdown]
# <font size ="5">
#
# Try it yourself! Test whether this is a 95% confidence interval

# %% [markdown]
# <font size = "3">
#
# Procedure:
# - Create a variable called "num_simulations" with value 1000
# - Create the simulation parameters "n", "population_mean", "populations_stdv".
# - Create an empty vector called "list_test_confidenceinterval".
# - Create a loop. At each iteration:
#
#     - Create a vector of normal random variables of size "n".
#     - Create a variable "test_confidenceinterval", which tests:
#
#         lower_bound $\quad \le \quad $ population_mean $\quad \le \quad$ upper_bound
#     - Append "test_confidenceinterval" to the above list
#
# - Compute the mean of "list_test_confidenceinterval"
#
# Note: The final result should be close to 95%.

# %%
# Write your own  code:
num_simulations = 1000
n = 10000
population_mean = 2
populations_stdv = 5
list_test_confidenceinterval = []
for iteration in range(num_simulations):
    X = np.random.normal(loc = population_mean, scale = populations_stdv, size = n)
    Xbar = X.mean()
    sample_stdv = X.std()
    lower_bound = Xbar - 1.96*(sample_stdv / np.sqrt(n))
    upper_bound = Xbar + 1.96*(sample_stdv / np.sqrt(n))
    if lower_bound <= population_mean <= upper_bound:
        list_test_confidenceinterval.append(1)
        coverage = np.mean(list_test_confidenceinterval)
        print("Coverage probability:", coverage)
    else: 
        list_test_confidenceinterval.append(0)
        print("Coverage probability not in the intervals")
# Out:
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability: 1.0
# Coverage probability not in the intervals
# Coverage probability: 0.9736842105263158
# Coverage probability: 0.9743589743589743
# Coverage probability: 0.975
# Coverage probability: 0.975609756097561
# Coverage probability not in the intervals
# Coverage probability: 0.9534883720930233
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9555555555555556
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.9574468085106383
# Coverage probability not in the intervals
# Coverage probability: 0.9387755102040817
# Coverage probability: 0.94
# Coverage probability: 0.9411764705882353
# Coverage probability: 0.9423076923076923
# Coverage probability: 0.9433962264150944
# Coverage probability: 0.9444444444444444
# Coverage probability: 0.9454545454545454
# Coverage probability: 0.9464285714285714
# Coverage probability: 0.9473684210526315
# Coverage probability: 0.9482758620689655
# Coverage probability: 0.9491525423728814
# Coverage probability: 0.95
# Coverage probability: 0.9508196721311475
# Coverage probability: 0.9516129032258065
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.953125
# Coverage probability: 0.9538461538461539
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9552238805970149
# Coverage probability: 0.9558823529411765
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.9571428571428572
# Coverage probability: 0.9577464788732394
# Coverage probability: 0.9583333333333334
# Coverage probability: 0.958904109589041
# Coverage probability: 0.9594594594594594
# Coverage probability: 0.96
# Coverage probability: 0.9605263157894737
# Coverage probability: 0.961038961038961
# Coverage probability: 0.9615384615384616
# Coverage probability: 0.9620253164556962
# Coverage probability: 0.9625
# Coverage probability not in the intervals
# Coverage probability: 0.9512195121951219
# Coverage probability: 0.9518072289156626
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9529411764705882
# Coverage probability: 0.9534883720930233
# Coverage probability: 0.9540229885057471
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9550561797752809
# Coverage probability: 0.9555555555555556
# Coverage probability: 0.9560439560439561
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.956989247311828
# Coverage probability: 0.9574468085106383
# Coverage probability: 0.9578947368421052
# Coverage probability: 0.9583333333333334
# Coverage probability: 0.9587628865979382
# Coverage probability: 0.9591836734693877
# Coverage probability: 0.9595959595959596
# Coverage probability: 0.96
# Coverage probability: 0.9603960396039604
# Coverage probability: 0.9607843137254902
# Coverage probability: 0.9611650485436893
# Coverage probability: 0.9615384615384616
# Coverage probability: 0.9619047619047619
# Coverage probability: 0.9622641509433962
# Coverage probability: 0.9626168224299065
# Coverage probability: 0.9629629629629629
# Coverage probability: 0.963302752293578
# Coverage probability: 0.9636363636363636
# Coverage probability: 0.963963963963964
# Coverage probability: 0.9642857142857143
# Coverage probability: 0.9646017699115044
# Coverage probability: 0.9649122807017544
# Coverage probability: 0.9652173913043478
# Coverage probability: 0.9655172413793104
# Coverage probability: 0.9658119658119658
# Coverage probability: 0.9661016949152542
# Coverage probability: 0.9663865546218487
# Coverage probability: 0.9666666666666667
# Coverage probability: 0.9669421487603306
# Coverage probability: 0.9672131147540983
# Coverage probability: 0.967479674796748
# Coverage probability: 0.967741935483871
# Coverage probability: 0.968
# Coverage probability: 0.9682539682539683
# Coverage probability: 0.968503937007874
# Coverage probability: 0.96875
# Coverage probability: 0.9689922480620154
# Coverage probability: 0.9692307692307692
# Coverage probability: 0.9694656488549618
# Coverage probability: 0.9696969696969697
# Coverage probability: 0.9699248120300752
# Coverage probability: 0.9701492537313433
# Coverage probability: 0.9703703703703703
# Coverage probability: 0.9705882352941176
# Coverage probability: 0.9708029197080292
# Coverage probability: 0.9710144927536232
# Coverage probability: 0.9712230215827338
# Coverage probability: 0.9714285714285714
# Coverage probability: 0.9716312056737588
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9583333333333334
# Coverage probability: 0.9586206896551724
# Coverage probability: 0.958904109589041
# Coverage probability: 0.9591836734693877
# Coverage probability: 0.9594594594594594
# Coverage probability: 0.959731543624161
# Coverage probability: 0.96
# Coverage probability: 0.9602649006622517
# Coverage probability: 0.9605263157894737
# Coverage probability: 0.9607843137254902
# Coverage probability: 0.961038961038961
# Coverage probability not in the intervals
# Coverage probability: 0.9551282051282052
# Coverage probability: 0.9554140127388535
# Coverage probability: 0.9556962025316456
# Coverage probability: 0.9559748427672956
# Coverage probability: 0.95625
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.9567901234567902
# Coverage probability: 0.9570552147239264
# Coverage probability: 0.9573170731707317
# Coverage probability: 0.9575757575757575
# Coverage probability: 0.9578313253012049
# Coverage probability: 0.9580838323353293
# Coverage probability: 0.9583333333333334
# Coverage probability: 0.9585798816568047
# Coverage probability: 0.9588235294117647
# Coverage probability: 0.9590643274853801
# Coverage probability: 0.9593023255813954
# Coverage probability: 0.9595375722543352
# Coverage probability: 0.9597701149425287
# Coverage probability: 0.96
# Coverage probability: 0.9602272727272727
# Coverage probability: 0.96045197740113
# Coverage probability: 0.9606741573033708
# Coverage probability: 0.9608938547486033
# Coverage probability: 0.9611111111111111
# Coverage probability: 0.9613259668508287
# Coverage probability: 0.9615384615384616
# Coverage probability: 0.9617486338797814
# Coverage probability: 0.9619565217391305
# Coverage probability: 0.9621621621621622
# Coverage probability: 0.9623655913978495
# Coverage probability: 0.9625668449197861
# Coverage probability: 0.9627659574468085
# Coverage probability: 0.9629629629629629
# Coverage probability: 0.9631578947368421
# Coverage probability: 0.9633507853403142
# Coverage probability: 0.9635416666666666
# Coverage probability: 0.9637305699481865
# Coverage probability: 0.9639175257731959
# Coverage probability: 0.9641025641025641
# Coverage probability: 0.9642857142857143
# Coverage probability: 0.9644670050761421
# Coverage probability: 0.9646464646464646
# Coverage probability: 0.964824120603015
# Coverage probability: 0.965
# Coverage probability: 0.9651741293532339
# Coverage probability: 0.9653465346534653
# Coverage probability: 0.9655172413793104
# Coverage probability: 0.9656862745098039
# Coverage probability: 0.9658536585365853
# Coverage probability: 0.9660194174757282
# Coverage probability: 0.966183574879227
# Coverage probability: 0.9663461538461539
# Coverage probability: 0.9665071770334929
# Coverage probability: 0.9666666666666667
# Coverage probability: 0.966824644549763
# Coverage probability: 0.9669811320754716
# Coverage probability: 0.9671361502347418
# Coverage probability not in the intervals
# Coverage probability: 0.9627906976744186
# Coverage probability: 0.9629629629629629
# Coverage probability: 0.9631336405529954
# Coverage probability: 0.963302752293578
# Coverage probability: 0.9634703196347032
# Coverage probability: 0.9636363636363636
# Coverage probability: 0.9638009049773756
# Coverage probability: 0.963963963963964
# Coverage probability: 0.9641255605381166
# Coverage probability: 0.9642857142857143
# Coverage probability: 0.9644444444444444
# Coverage probability: 0.9646017699115044
# Coverage probability: 0.9647577092511013
# Coverage probability: 0.9649122807017544
# Coverage probability: 0.9650655021834061
# Coverage probability: 0.9652173913043478
# Coverage probability: 0.9653679653679653
# Coverage probability: 0.9655172413793104
# Coverage probability: 0.9656652360515021
# Coverage probability: 0.9658119658119658
# Coverage probability: 0.9659574468085106
# Coverage probability: 0.9661016949152542
# Coverage probability: 0.9662447257383966
# Coverage probability: 0.9663865546218487
# Coverage probability: 0.9665271966527197
# Coverage probability: 0.9666666666666667
# Coverage probability: 0.966804979253112
# Coverage probability: 0.9669421487603306
# Coverage probability: 0.9670781893004116
# Coverage probability: 0.9672131147540983
# Coverage probability: 0.9673469387755103
# Coverage probability: 0.967479674796748
# Coverage probability: 0.9676113360323887
# Coverage probability: 0.967741935483871
# Coverage probability: 0.9678714859437751
# Coverage probability: 0.968
# Coverage probability: 0.9681274900398407
# Coverage probability not in the intervals
# Coverage probability: 0.9644268774703557
# Coverage probability: 0.9645669291338582
# Coverage probability: 0.9647058823529412
# Coverage probability: 0.96484375
# Coverage probability: 0.9649805447470817
# Coverage probability: 0.9651162790697675
# Coverage probability: 0.9652509652509652
# Coverage probability: 0.9653846153846154
# Coverage probability: 0.9655172413793104
# Coverage probability: 0.9656488549618321
# Coverage probability: 0.9657794676806084
# Coverage probability: 0.9659090909090909
# Coverage probability: 0.9660377358490566
# Coverage probability not in the intervals
# Coverage probability: 0.9625468164794008
# Coverage probability: 0.9626865671641791
# Coverage probability: 0.9628252788104089
# Coverage probability: 0.9629629629629629
# Coverage probability: 0.9630996309963099
# Coverage probability: 0.9632352941176471
# Coverage probability: 0.9633699633699634
# Coverage probability not in the intervals
# Coverage probability: 0.96
# Coverage probability: 0.9601449275362319
# Coverage probability: 0.9602888086642599
# Coverage probability: 0.960431654676259
# Coverage probability: 0.9605734767025089
# Coverage probability: 0.9607142857142857
# Coverage probability: 0.9608540925266904
# Coverage probability: 0.9609929078014184
# Coverage probability: 0.9611307420494699
# Coverage probability: 0.9612676056338029
# Coverage probability: 0.9614035087719298
# Coverage probability: 0.9615384615384616
# Coverage probability: 0.9616724738675958
# Coverage probability: 0.9618055555555556
# Coverage probability: 0.9619377162629758
# Coverage probability: 0.9620689655172414
# Coverage probability: 0.9621993127147767
# Coverage probability: 0.9623287671232876
# Coverage probability: 0.962457337883959
# Coverage probability: 0.9625850340136054
# Coverage probability: 0.9627118644067797
# Coverage probability: 0.9628378378378378
# Coverage probability: 0.9629629629629629
# Coverage probability: 0.9630872483221476
# Coverage probability not in the intervals
# Coverage probability: 0.96
# Coverage probability: 0.9601328903654485
# Coverage probability: 0.9602649006622517
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9540983606557377
# Coverage probability: 0.954248366013072
# Coverage probability: 0.9543973941368078
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9546925566343042
# Coverage probability: 0.9548387096774194
# Coverage probability: 0.954983922829582
# Coverage probability: 0.9551282051282052
# Coverage probability: 0.9552715654952076
# Coverage probability: 0.9554140127388535
# Coverage probability: 0.9555555555555556
# Coverage probability not in the intervals
# Coverage probability: 0.9526813880126183
# Coverage probability not in the intervals
# Coverage probability: 0.9498432601880877
# Coverage probability not in the intervals
# Coverage probability: 0.9470404984423676
# Coverage probability: 0.9472049689440993
# Coverage probability: 0.9473684210526315
# Coverage probability: 0.9475308641975309
# Coverage probability: 0.9476923076923077
# Coverage probability: 0.9478527607361963
# Coverage probability: 0.9480122324159022
# Coverage probability: 0.948170731707317
# Coverage probability: 0.9483282674772037
# Coverage probability: 0.9484848484848485
# Coverage probability: 0.9486404833836858
# Coverage probability: 0.9487951807228916
# Coverage probability: 0.948948948948949
# Coverage probability: 0.9491017964071856
# Coverage probability: 0.9492537313432836
# Coverage probability: 0.9494047619047619
# Coverage probability: 0.9495548961424333
# Coverage probability: 0.9497041420118343
# Coverage probability: 0.9498525073746312
# Coverage probability: 0.95
# Coverage probability: 0.9501466275659824
# Coverage probability: 0.9502923976608187
# Coverage probability: 0.9504373177842566
# Coverage probability: 0.9505813953488372
# Coverage probability: 0.9507246376811594
# Coverage probability: 0.9508670520231214
# Coverage probability: 0.9510086455331412
# Coverage probability: 0.9511494252873564
# Coverage probability: 0.9512893982808023
# Coverage probability: 0.9514285714285714
# Coverage probability: 0.9515669515669516
# Coverage probability: 0.9517045454545454
# Coverage probability: 0.9518413597733711
# Coverage probability: 0.9519774011299436
# Coverage probability: 0.952112676056338
# Coverage probability: 0.952247191011236
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.952513966480447
# Coverage probability: 0.9526462395543176
# Coverage probability: 0.9527777777777777
# Coverage probability: 0.9529085872576177
# Coverage probability: 0.9530386740331491
# Coverage probability: 0.953168044077135
# Coverage probability: 0.9532967032967034
# Coverage probability: 0.9534246575342465
# Coverage probability: 0.953551912568306
# Coverage probability: 0.9536784741144414
# Coverage probability: 0.9538043478260869
# Coverage probability: 0.9539295392953929
# Coverage probability: 0.9540540540540541
# Coverage probability: 0.954177897574124
# Coverage probability: 0.9543010752688172
# Coverage probability not in the intervals
# Coverage probability: 0.9518716577540107
# Coverage probability: 0.952
# Coverage probability: 0.9521276595744681
# Coverage probability: 0.9522546419098143
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9525065963060686
# Coverage probability: 0.9526315789473684
# Coverage probability: 0.952755905511811
# Coverage probability: 0.9528795811518325
# Coverage probability: 0.9530026109660574
# Coverage probability: 0.953125
# Coverage probability: 0.9532467532467532
# Coverage probability: 0.9533678756476683
# Coverage probability: 0.9534883720930233
# Coverage probability: 0.9536082474226805
# Coverage probability: 0.9537275064267352
# Coverage probability: 0.9538461538461539
# Coverage probability: 0.9539641943734015
# Coverage probability: 0.9540816326530612
# Coverage probability: 0.9541984732824428
# Coverage probability: 0.9543147208121827
# Coverage probability: 0.9544303797468354
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9546599496221663
# Coverage probability: 0.9547738693467337
# Coverage probability: 0.9548872180451128
# Coverage probability: 0.955
# Coverage probability: 0.9551122194513716
# Coverage probability: 0.9552238805970149
# Coverage probability: 0.9553349875930521
# Coverage probability not in the intervals
# Coverage probability: 0.9530864197530864
# Coverage probability: 0.9532019704433498
# Coverage probability: 0.9533169533169533
# Coverage probability: 0.9534313725490197
# Coverage probability: 0.9535452322738386
# Coverage probability not in the intervals
# Coverage probability: 0.9513381995133819
# Coverage probability: 0.9514563106796117
# Coverage probability: 0.9515738498789347
# Coverage probability: 0.9516908212560387
# Coverage probability: 0.9518072289156626
# Coverage probability: 0.9519230769230769
# Coverage probability: 0.9520383693045563
# Coverage probability: 0.9521531100478469
# Coverage probability: 0.9522673031026253
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9524940617577197
# Coverage probability: 0.95260663507109
# Coverage probability: 0.9527186761229315
# Coverage probability: 0.9528301886792453
# Coverage probability: 0.9529411764705882
# Coverage probability: 0.9530516431924883
# Coverage probability: 0.9531615925058547
# Coverage probability: 0.9532710280373832
# Coverage probability: 0.9533799533799534
# Coverage probability not in the intervals
# Coverage probability: 0.951276102088167
# Coverage probability: 0.9513888888888888
# Coverage probability: 0.9515011547344111
# Coverage probability: 0.9516129032258065
# Coverage probability: 0.9517241379310345
# Coverage probability: 0.9518348623853211
# Coverage probability: 0.9519450800915332
# Coverage probability: 0.952054794520548
# Coverage probability: 0.9521640091116174
# Coverage probability: 0.9522727272727273
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9524886877828054
# Coverage probability: 0.9525959367945824
# Coverage probability: 0.9527027027027027
# Coverage probability: 0.952808988764045
# Coverage probability: 0.952914798206278
# Coverage probability: 0.9530201342281879
# Coverage probability: 0.953125
# Coverage probability: 0.9532293986636972
# Coverage probability: 0.9533333333333334
# Coverage probability: 0.9534368070953437
# Coverage probability: 0.9535398230088495
# Coverage probability: 0.9536423841059603
# Coverage probability: 0.9537444933920705
# Coverage probability: 0.9538461538461539
# Coverage probability: 0.9539473684210527
# Coverage probability: 0.9540481400437637
# Coverage probability: 0.9541484716157205
# Coverage probability: 0.954248366013072
# Coverage probability: 0.9543478260869566
# Coverage probability: 0.9544468546637744
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9546436285097192
# Coverage probability: 0.9547413793103449
# Coverage probability: 0.9548387096774194
# Coverage probability: 0.9549356223175965
# Coverage probability: 0.9550321199143469
# Coverage probability: 0.9551282051282052
# Coverage probability: 0.9552238805970149
# Coverage probability: 0.9553191489361702
# Coverage probability: 0.9554140127388535
# Coverage probability: 0.9555084745762712
# Coverage probability: 0.9556025369978859
# Coverage probability: 0.9556962025316456
# Coverage probability: 0.9557894736842105
# Coverage probability: 0.9558823529411765
# Coverage probability: 0.9559748427672956
# Coverage probability: 0.9560669456066946
# Coverage probability: 0.9561586638830898
# Coverage probability: 0.95625
# Coverage probability: 0.9563409563409564
# Coverage probability: 0.9564315352697096
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.9566115702479339
# Coverage probability: 0.9567010309278351
# Coverage probability not in the intervals
# Coverage probability: 0.9548254620123203
# Coverage probability not in the intervals
# Coverage probability: 0.9529652351738241
# Coverage probability: 0.9530612244897959
# Coverage probability: 0.9531568228105907
# Coverage probability: 0.9532520325203252
# Coverage probability: 0.9533468559837728
# Coverage probability: 0.9534412955465587
# Coverage probability: 0.9535353535353536
# Coverage probability: 0.9536290322580645
# Coverage probability: 0.9537223340040242
# Coverage probability: 0.9538152610441767
# Coverage probability: 0.9539078156312625
# Coverage probability: 0.954
# Coverage probability: 0.9540918163672655
# Coverage probability: 0.954183266932271
# Coverage probability: 0.9542743538767395
# Coverage probability: 0.9543650793650794
# Coverage probability: 0.9544554455445544
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9546351084812623
# Coverage probability: 0.9547244094488189
# Coverage probability: 0.9548133595284872
# Coverage probability: 0.9549019607843138
# Coverage probability: 0.9549902152641878
# Coverage probability: 0.955078125
# Coverage probability not in the intervals
# Coverage probability: 0.953307392996109
# Coverage probability: 0.9533980582524272
# Coverage probability: 0.9534883720930233
# Coverage probability: 0.9535783365570599
# Coverage probability: 0.9536679536679536
# Coverage probability: 0.953757225433526
# Coverage probability: 0.9538461538461539
# Coverage probability: 0.9539347408829175
# Coverage probability: 0.9540229885057471
# Coverage probability: 0.9541108986615678
# Coverage probability: 0.9541984732824428
# Coverage probability: 0.9542857142857143
# Coverage probability: 0.9543726235741445
# Coverage probability: 0.9544592030360531
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9546313799621928
# Coverage probability: 0.9547169811320755
# Coverage probability: 0.9548022598870056
# Coverage probability: 0.9548872180451128
# Coverage probability: 0.9549718574108818
# Coverage probability: 0.9550561797752809
# Coverage probability: 0.9551401869158879
# Coverage probability: 0.9552238805970149
# Coverage probability: 0.9553072625698324
# Coverage probability: 0.9553903345724907
# Coverage probability not in the intervals
# Coverage probability: 0.9537037037037037
# Coverage probability: 0.9537892791127541
# Coverage probability: 0.9538745387453874
# Coverage probability: 0.9539594843462247
# Coverage probability: 0.9540441176470589
# Coverage probability: 0.9541284403669725
# Coverage probability: 0.9542124542124543
# Coverage probability: 0.9542961608775137
# Coverage probability: 0.9543795620437956
# Coverage probability: 0.9544626593806922
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9546279491833031
# Coverage probability: 0.9547101449275363
# Coverage probability: 0.9547920433996383
# Coverage probability: 0.9548736462093863
# Coverage probability: 0.954954954954955
# Coverage probability: 0.9550359712230215
# Coverage probability: 0.9551166965888689
# Coverage probability: 0.9551971326164874
# Coverage probability: 0.9552772808586762
# Coverage probability: 0.9553571428571429
# Coverage probability: 0.9554367201426025
# Coverage probability: 0.9555160142348754
# Coverage probability: 0.955595026642984
# Coverage probability: 0.9556737588652482
# Coverage probability: 0.9557522123893806
# Coverage probability: 0.9558303886925795
# Coverage probability: 0.9559082892416225
# Coverage probability: 0.9559859154929577
# Coverage probability: 0.9560632688927944
# Coverage probability: 0.956140350877193
# Coverage probability: 0.9562171628721541
# Coverage probability: 0.9562937062937062
# Coverage probability: 0.956369982547993
# Coverage probability: 0.9564459930313589
# Coverage probability: 0.9565217391304348
# Coverage probability: 0.9565972222222222
# Coverage probability: 0.9566724436741768
# Coverage probability: 0.9567474048442907
# Coverage probability: 0.9568221070811744
# Coverage probability: 0.9568965517241379
# Coverage probability: 0.9569707401032702
# Coverage probability: 0.9570446735395189
# Coverage probability: 0.9571183533447685
# Coverage probability: 0.9571917808219178
# Coverage probability: 0.9572649572649573
# Coverage probability: 0.9573378839590444
# Coverage probability: 0.9574105621805792
# Coverage probability: 0.9574829931972789
# Coverage probability: 0.9575551782682513
# Coverage probability: 0.9576271186440678
# Coverage probability: 0.9576988155668359
# Coverage probability: 0.9577702702702703
# Coverage probability: 0.9578414839797639
# Coverage probability: 0.9579124579124579
# Coverage probability: 0.957983193277311
# Coverage probability: 0.9580536912751678
# Coverage probability: 0.9581239530988275
# Coverage probability: 0.9581939799331104
# Coverage probability: 0.9582637729549248
# Coverage probability: 0.9583333333333334
# Coverage probability not in the intervals
# Coverage probability: 0.9568106312292359
# Coverage probability: 0.956882255389718
# Coverage probability: 0.956953642384106
# Coverage probability: 0.9570247933884297
# Coverage probability: 0.9570957095709571
# Coverage probability: 0.957166392092257
# Coverage probability: 0.9572368421052632
# Coverage probability not in the intervals
# Coverage probability: 0.9557377049180328
# Coverage probability: 0.955810147299509
# Coverage probability: 0.9558823529411765
# Coverage probability: 0.9559543230016313
# Coverage probability: 0.9560260586319218
# Coverage probability: 0.9560975609756097
# Coverage probability: 0.9561688311688312
# Coverage probability: 0.9562398703403565
# Coverage probability: 0.9563106796116505
# Coverage probability: 0.9563812600969306
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9533762057877814
# Coverage probability: 0.9534510433386838
# Coverage probability not in the intervals
# Coverage probability: 0.952
# Coverage probability: 0.952076677316294
# Coverage probability: 0.9521531100478469
# Coverage probability: 0.9522292993630573
# Coverage probability: 0.9523052464228935
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9524564183835182
# Coverage probability: 0.9525316455696202
# Coverage probability: 0.95260663507109
# Coverage probability: 0.9526813880126183
# Coverage probability: 0.952755905511811
# Coverage probability: 0.9528301886792453
# Coverage probability: 0.9529042386185244
# Coverage probability: 0.9529780564263323
# Coverage probability: 0.9530516431924883
# Coverage probability: 0.953125
# Coverage probability: 0.953198127925117
# Coverage probability: 0.9532710280373832
# Coverage probability: 0.9533437013996889
# Coverage probability: 0.953416149068323
# Coverage probability: 0.9534883720930233
# Coverage probability: 0.9535603715170279
# Coverage probability: 0.9536321483771252
# Coverage probability: 0.9537037037037037
# Coverage probability: 0.9537750385208013
# Coverage probability: 0.9538461538461539
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9509954058192955
# Coverage probability: 0.9510703363914373
# Coverage probability: 0.9511450381679389
# Coverage probability: 0.9512195121951219
# Coverage probability: 0.9512937595129376
# Coverage probability: 0.9513677811550152
# Coverage probability: 0.9514415781487102
# Coverage probability: 0.9515151515151515
# Coverage probability: 0.9515885022692889
# Coverage probability: 0.9516616314199395
# Coverage probability: 0.951734539969834
# Coverage probability: 0.9518072289156626
# Coverage probability: 0.9518796992481203
# Coverage probability: 0.9519519519519519
# Coverage probability: 0.952023988005997
# Coverage probability: 0.9520958083832335
# Coverage probability: 0.9521674140508222
# Coverage probability: 0.9522388059701492
# Coverage probability: 0.9523099850968704
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9524517087667161
# Coverage probability: 0.9525222551928784
# Coverage probability: 0.9525925925925925
# Coverage probability: 0.9526627218934911
# Coverage probability: 0.9527326440177253
# Coverage probability: 0.9528023598820059
# Coverage probability: 0.9528718703976435
# Coverage probability not in the intervals
# Coverage probability: 0.9515418502202643
# Coverage probability: 0.9516129032258065
# Coverage probability: 0.9516837481698389
# Coverage probability: 0.9517543859649122
# Coverage probability: 0.9518248175182482
# Coverage probability: 0.9518950437317785
# Coverage probability: 0.9519650655021834
# Coverage probability: 0.9520348837209303
# Coverage probability: 0.9521044992743106
# Coverage probability: 0.9521739130434783
# Coverage probability: 0.9522431259044862
# Coverage probability: 0.9523121387283237
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.952449567723343
# Coverage probability: 0.9525179856115108
# Coverage probability: 0.9525862068965517
# Coverage probability: 0.9526542324246772
# Coverage probability: 0.9527220630372493
# Coverage probability: 0.9527896995708155
# Coverage probability: 0.9528571428571428
# Coverage probability: 0.9529243937232525
# Coverage probability: 0.9529914529914529
# Coverage probability: 0.9530583214793741
# Coverage probability: 0.953125
# Coverage probability: 0.9531914893617022
# Coverage probability: 0.953257790368272
# Coverage probability: 0.9533239038189534
# Coverage probability: 0.9533898305084746
# Coverage probability: 0.9534555712270804
# Coverage probability: 0.9535211267605633
# Coverage probability: 0.9535864978902954
# Coverage probability: 0.9536516853932584
# Coverage probability: 0.9537166900420757
# Coverage probability: 0.9537815126050421
# Coverage probability: 0.9538461538461539
# Coverage probability: 0.9539106145251397
# Coverage probability: 0.9539748953974896
# Coverage probability: 0.9540389972144847
# Coverage probability: 0.9541029207232267
# Coverage probability: 0.9541666666666667
# Coverage probability: 0.9542302357836339
# Coverage probability: 0.9542936288088643
# Coverage probability: 0.9543568464730291
# Coverage probability not in the intervals
# Coverage probability: 0.953103448275862
# Coverage probability: 0.953168044077135
# Coverage probability: 0.953232462173315
# Coverage probability: 0.9532967032967034
# Coverage probability: 0.953360768175583
# Coverage probability: 0.9534246575342465
# Coverage probability: 0.9534883720930233
# Coverage probability: 0.953551912568306
# Coverage probability: 0.9536152796725784
# Coverage probability: 0.9536784741144414
# Coverage probability: 0.9537414965986395
# Coverage probability not in the intervals
# Coverage probability: 0.9525101763907734
# Coverage probability: 0.9525745257452575
# Coverage probability not in the intervals
# Coverage probability: 0.9513513513513514
# Coverage probability: 0.951417004048583
# Coverage probability: 0.9514824797843666
# Coverage probability: 0.9515477792732167
# Coverage probability: 0.9516129032258065
# Coverage probability: 0.9516778523489933
# Coverage probability: 0.9517426273458445
# Coverage probability: 0.9518072289156626
# Coverage probability: 0.9518716577540107
# Coverage probability: 0.951935914552737
# Coverage probability: 0.952
# Coverage probability: 0.952063914780293
# Coverage probability: 0.9521276595744681
# Coverage probability: 0.952191235059761
# Coverage probability: 0.9522546419098143
# Coverage probability: 0.952317880794702
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.952443857331572
# Coverage probability: 0.9525065963060686
# Coverage probability: 0.9525691699604744
# Coverage probability: 0.9526315789473684
# Coverage probability: 0.9526938239159002
# Coverage probability: 0.952755905511811
# Coverage probability: 0.9528178243774574
# Coverage probability: 0.9528795811518325
# Coverage probability: 0.9529411764705882
# Coverage probability: 0.9530026109660574
# Coverage probability: 0.9530638852672751
# Coverage probability: 0.953125
# Coverage probability: 0.953185955786736
# Coverage probability: 0.9532467532467532
# Coverage probability: 0.953307392996109
# Coverage probability: 0.9533678756476683
# Coverage probability: 0.9534282018111255
# Coverage probability not in the intervals
# Coverage probability: 0.952258064516129
# Coverage probability: 0.9523195876288659
# Coverage probability: 0.9523809523809523
# Coverage probability not in the intervals
# Coverage probability: 0.9512195121951219
# Coverage probability: 0.9512820512820512
# Coverage probability: 0.9513444302176697
# Coverage probability: 0.9514066496163683
# Coverage probability: 0.9514687100893997
# Coverage probability not in the intervals
# Coverage probability: 0.9503184713375796
# Coverage probability: 0.950381679389313
# Coverage probability: 0.9504447268106735
# Coverage probability: 0.950507614213198
# Coverage probability: 0.9505703422053232
# Coverage probability: 0.950632911392405
# Coverage probability: 0.9506953223767383
# Coverage probability: 0.9507575757575758
# Coverage probability: 0.9508196721311475
# Coverage probability: 0.9508816120906801
# Coverage probability: 0.9509433962264151
# Coverage probability: 0.9510050251256281
# Coverage probability: 0.9510664993726474
# Coverage probability: 0.9511278195488722
# Coverage probability: 0.951188986232791
# Coverage probability: 0.95125
# Coverage probability: 0.951310861423221
# Coverage probability: 0.9513715710723192
# Coverage probability: 0.9514321295143213
# Coverage probability: 0.9514925373134329
# Coverage probability: 0.9515527950310559
# Coverage probability: 0.9516129032258065
# Coverage probability: 0.9516728624535316
# Coverage probability: 0.9517326732673267
# Coverage probability: 0.9517923362175525
# Coverage probability: 0.9518518518518518
# Coverage probability: 0.9519112207151664
# Coverage probability: 0.9519704433497537
# Coverage probability: 0.9520295202952029
# Coverage probability: 0.952088452088452
# Coverage probability: 0.9521472392638037
# Coverage probability: 0.9522058823529411
# Coverage probability: 0.9522643818849449
# Coverage probability: 0.9523227383863081
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.9524390243902439
# Coverage probability: 0.9524969549330086
# Coverage probability: 0.9525547445255474
# Coverage probability: 0.9526123936816525
# Coverage probability: 0.9526699029126213
# Coverage probability: 0.9527272727272728
# Coverage probability: 0.9527845036319612
# Coverage probability: 0.9528415961305925
# Coverage probability: 0.9528985507246377
# Coverage probability: 0.9529553679131484
# Coverage probability: 0.9530120481927711
# Coverage probability: 0.9530685920577617
# Coverage probability: 0.953125
# Coverage probability: 0.9531812725090036
# Coverage probability: 0.9532374100719424
# Coverage probability: 0.9532934131736527
# Coverage probability: 0.9533492822966507
# Coverage probability: 0.953405017921147
# Coverage probability: 0.9534606205250596
# Coverage probability: 0.9535160905840286
# Coverage probability: 0.9535714285714286
# Coverage probability: 0.9536266349583828
# Coverage probability: 0.9536817102137767
# Coverage probability: 0.9537366548042705
# Coverage probability: 0.9537914691943128
# Coverage probability: 0.9538461538461539
# Coverage probability: 0.9539007092198581
# Coverage probability: 0.9539551357733176
# Coverage probability: 0.9540094339622641
# Coverage probability: 0.9540636042402827
# Coverage probability: 0.9541176470588235
# Coverage probability: 0.954171562867215
# Coverage probability: 0.954225352112676
# Coverage probability: 0.9542790152403282
# Coverage probability: 0.9543325526932084
# Coverage probability: 0.9543859649122807
# Coverage probability: 0.9544392523364486
# Coverage probability: 0.9544924154025671
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9545983701979045
# Coverage probability: 0.9546511627906977
# Coverage probability: 0.9547038327526133
# Coverage probability: 0.9547563805104409
# Coverage probability: 0.9548088064889919
# Coverage probability: 0.9548611111111112
# Coverage probability not in the intervals
# Coverage probability: 0.953810623556582
# Coverage probability: 0.9538638985005767
# Coverage probability: 0.9539170506912442
# Coverage probability: 0.953970080552359
# Coverage probability: 0.9540229885057471
# Coverage probability: 0.9540757749712974
# Coverage probability: 0.9541284403669725
# Coverage probability: 0.9541809851088202
# Coverage probability: 0.954233409610984
# Coverage probability: 0.9542857142857143
# Coverage probability: 0.954337899543379
# Coverage probability: 0.9543899657924744
# Coverage probability: 0.9544419134396356
# Coverage probability: 0.9544937428896473
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9545970488081725
# Coverage probability: 0.9546485260770975
# Coverage probability: 0.9546998867497168
# Coverage probability: 0.9547511312217195
# Coverage probability: 0.9548022598870056
# Coverage probability: 0.9548532731376975
# Coverage probability: 0.9549041713641488
# Coverage probability not in the intervals
# Coverage probability: 0.953880764904387
# Coverage probability: 0.9539325842696629
# Coverage probability: 0.9539842873176206
# Coverage probability: 0.9540358744394619
# Coverage probability: 0.9540873460246361
# Coverage probability: 0.9541387024608501
# Coverage probability: 0.9541899441340782
# Coverage probability: 0.9542410714285714
# Coverage probability: 0.9542920847268673
# Coverage probability: 0.9543429844097996
# Coverage probability: 0.9543937708565072
# Coverage probability: 0.9544444444444444
# Coverage probability: 0.9544950055493896
# Coverage probability: 0.9545454545454546
# Coverage probability: 0.9545957918050941
# Coverage probability: 0.9546460176991151
# Coverage probability: 0.9546961325966851
# Coverage probability: 0.9547461368653422
# Coverage probability: 0.9547960308710033
# Coverage probability: 0.9548458149779736
# Coverage probability: 0.9548954895489549
# Coverage probability: 0.954945054945055
# Coverage probability: 0.9549945115257958
# Coverage probability: 0.9550438596491229
# Coverage probability: 0.9550930996714129
# Coverage probability: 0.9551422319474836
# Coverage probability: 0.9551912568306011
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9531590413943355
# Coverage probability: 0.9532100108813928
# Coverage probability: 0.9532608695652174
# Coverage probability: 0.9533116178067318
# Coverage probability: 0.9533622559652929
# Coverage probability: 0.9534127843986999
# Coverage probability: 0.9534632034632035
# Coverage probability: 0.9535135135135135
# Coverage probability: 0.9535637149028078
# Coverage probability: 0.95361380798274
# Coverage probability: 0.9536637931034483
# Coverage probability: 0.9537136706135629
# Coverage probability: 0.953763440860215
# Coverage probability: 0.9538131041890441
# Coverage probability: 0.953862660944206
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9518716577540107
# Coverage probability: 0.9519230769230769
# Coverage probability: 0.951974386339381
# Coverage probability: 0.9520255863539445
# Coverage probability: 0.952076677316294
# Coverage probability: 0.9521276595744681
# Coverage probability: 0.9521785334750266
# Coverage probability: 0.9522292993630573
# Coverage probability: 0.9522799575821845
# Coverage probability: 0.9523305084745762
# Coverage probability: 0.9523809523809523
# Coverage probability: 0.952431289640592
# Coverage probability: 0.9524815205913411
# Coverage probability: 0.9525316455696202
# Coverage probability: 0.9525816649104321
# Coverage probability: 0.9526315789473684
# Coverage probability: 0.9526813880126183
# Coverage probability: 0.9527310924369747
# Coverage probability: 0.9527806925498427
# Coverage probability: 0.9528301886792453
# Coverage probability: 0.9528795811518325
# Coverage probability: 0.952928870292887
# Coverage probability: 0.9529780564263323
# Coverage probability: 0.9530271398747391
# Coverage probability: 0.9530761209593326
# Coverage probability: 0.953125
# Coverage probability: 0.9531737773152965
# Coverage probability not in the intervals
# Coverage probability: 0.952232606438214
# Coverage probability: 0.9522821576763485
# Coverage probability not in the intervals
# Coverage probability not in the intervals
# Coverage probability: 0.9503619441571872
# Coverage probability: 0.9504132231404959
# Coverage probability: 0.9504643962848297
# Coverage probability: 0.9505154639175257
# Coverage probability: 0.9505664263645726
# Coverage probability: 0.9506172839506173
# Coverage probability: 0.9506680369989723
# Coverage probability: 0.9507186858316222
# Coverage probability: 0.9507692307692308
# Coverage probability not in the intervals
# Coverage probability: 0.9498464687819856
# Coverage probability: 0.9498977505112475
# Coverage probability: 0.9499489274770173
# Coverage probability: 0.95
# Coverage probability: 0.9500509683995922
# Coverage probability: 0.9501018329938901
# Coverage probability: 0.9501525940996948
# Coverage probability not in the intervals
# Coverage probability: 0.949238578680203
# Coverage probability: 0.949290060851927
# Coverage probability: 0.9493414387031408
# Coverage probability: 0.9493927125506073
# Coverage probability: 0.9494438827098078
# Coverage probability: 0.9494949494949495
# Coverage probability: 0.9495459132189707
# Coverage probability: 0.9495967741935484
# Coverage probability: 0.9496475327291037
# Coverage probability: 0.9496981891348089
# Coverage probability: 0.949748743718593
# Coverage probability: 0.9497991967871486
# Coverage probability: 0.9498495486459378
# Coverage probability: 0.9498997995991983
# Coverage probability: 0.94994994994995
# Coverage probability: 0.95
